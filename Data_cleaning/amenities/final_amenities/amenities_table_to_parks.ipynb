# %%
import geopandas as gpd 
from shapely.wkt import loads

# %%
from shapely import wkt
from shapely.geometry import Point

# %%
import folium
import mapclassify

# %%
unique_parks_gdf= gpd.read_file('unique_parks_50%.geojson',index=False)

# %%
unique_parks_gdf.head()
# Out:
#   park_id              park_name  \
# 0   PK101       Inwood Hill Park
# 1   PK102  Irish Hunger Memorial
# 2   PK103             Isham Park
# 3   PK104    J. Hood Wright Park
# 4   PK105   Jackie Robinson Park
#
#                                             geometry
# 0  POLYGON ((-73.93200 40.86963, -73.93201 40.869...
# 1  POLYGON ((-74.01610 40.71514, -74.01607 40.715...
# 2  POLYGON ((-73.91930 40.86841, -73.91977 40.869...
# 3  POLYGON ((-73.94070 40.84554, -73.94250 40.846...
# 4  POLYGON ((-73.93954 40.82964, -73.93955 40.829...

# %%
unique_parks_gdf.to_csv('unique_parks1.csv',index=False)

# %%
unique_parks_gdf.shape
# Out:
# (191, 3)

# %%
type(unique_parks_gdf)
# Out:
# geopandas.geodataframe.GeoDataFrame

# %%
unique_parks_gdf = unique_parks_gdf.to_crs(epsg=32618)

# %%
unique_parks_gdf.crs
# Out:
# <Projected CRS: EPSG:32618>
# Name: WGS 84 / UTM zone 18N
# Axis Info [cartesian]:
# - E[east]: Easting (metre)
# - N[north]: Northing (metre)
# Area of Use:
# - name: Between 78°W and 72°W, northern hemisphere between equator and 84°N, onshore and offshore. Bahamas. Canada - Nunavut; Ontario; Quebec. Colombia. Cuba. Ecuador. Greenland. Haiti. Jamaica. Panama. Turks and Caicos Islands. United States (USA). Venezuela.
# - bounds: (-78.0, 0.0, -72.0, 84.0)
# Coordinate Operation:
# - name: UTM zone 18N
# - method: Transverse Mercator
# Datum: World Geodetic System 1984 ensemble
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %%
unique_parks_gdf=unique_parks_gdf.set_geometry('geometry')

# %%
unique_parks_gdf=unique_parks_gdf.to_crs(epsg=32618)

# %%
unique_parks_gdf.explore()
# Out:
# c:\Users\Justh\anaconda3\envs\comp47360\Lib\site-packages\folium\features.py:1155: UserWarning: GeoJsonTooltip is not configured to render for GeoJson GeometryCollection geometries. Please consider reworking these features: [{'park_id': 'PK48', 'park_name': 'Cherry Tree Park'}] to MultiPolygon for full functionality.
# https://tools.ietf.org/html/rfc7946#page-9
#   warnings.warn(
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
# ...

# %% [markdown]
# Load the 'cafe' amenity

# %%
cafe_gdf= gpd.read_file('cafe_details.geojson')

# %%
cafe_gdf.head()
# Out:
#    cafe_id               name                                   centroid_wkt  \
# 0        1  Le Pain Quotidien  POINT (-73.99499240499324 40.726359729888976)
# 1        2        Bagel Belly    POINT (-73.9877021475679 40.73307288359512)
# 2        3  Le Pain Quotidien  POINT (-73.98970841908216 40.740385378908755)
# 3        4     Bluestone Lane  POINT (-74.00283483895498 40.730015992741556)
# 4        5  La Contenta Oeste   POINT (-73.99807139718752 40.73515497208401)
#
#                                             geometry
# 0  POLYGON ((-73.99488 40.72633, -73.99479 40.726...
# 1  POLYGON ((-73.98755 40.73306, -73.98766 40.733...
# 2  POLYGON ((-73.98978 40.74036, -73.98965 40.740...
# 3  POLYGON ((-74.00281 40.73004, -74.00281 40.730...
# 4  POLYGON ((-73.99806 40.73510, -73.99790 40.735...

# %%
cafe_gdf=cafe_gdf.drop(columns='centroid_wkt',axis=1)

# %%
cafe_gdf=cafe_gdf.to_crs(epsg=32618)

# %%
cafe_gdf['centroid']=cafe_gdf.centroid

# %%
cafe_gdf= cafe_gdf.rename({'name':'cafe_name'},axis=1)

# %%
cafe_gdf= cafe_gdf.set_geometry('centroid')

# %%
cafe_gdf.geometry.name
# Out:
# 'centroid'

# %%
cafe_gdf.crs
#ensure there are the same CRS
# Out:
# <Projected CRS: EPSG:32618>
# Name: WGS 84 / UTM zone 18N
# Axis Info [cartesian]:
# - E[east]: Easting (metre)
# - N[north]: Northing (metre)
# Area of Use:
# - name: Between 78°W and 72°W, northern hemisphere between equator and 84°N, onshore and offshore. Bahamas. Canada - Nunavut; Ontario; Quebec. Colombia. Cuba. Ecuador. Greenland. Haiti. Jamaica. Panama. Turks and Caicos Islands. United States (USA). Venezuela.
# - bounds: (-78.0, 0.0, -72.0, 84.0)
# Coordinate Operation:
# - name: UTM zone 18N
# - method: Transverse Mercator
# Datum: World Geodetic System 1984 ensemble
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %%
unique_parks_gdf= unique_parks_gdf.to_crs(epsg=32618)

# %%
unique_parks_gdf= unique_parks_gdf.set_geometry('geometry')

# %% [markdown]
# Create buffers around park

# %%
# Set the geometry to the buffer
parks_with_buffers = unique_parks_gdf

# %%
# Create a buffer around each park
parks_with_buffers['buffer'] = parks_with_buffers.geometry.buffer(100)

# %%
parks_with_buffers=parks_with_buffers.set_geometry('buffer')

# %%
parks_with_buffers.geometry.name
# Out:
# 'buffer'

# %%
parks_with_buffers.head()
# Out:
#   park_id              park_name  \
# 0   PK101       Inwood Hill Park
# 1   PK102  Irish Hunger Memorial
# 2   PK103             Isham Park
# 3   PK104    J. Hood Wright Park
# 4   PK105   Jackie Robinson Park
#
#                                             geometry  \
# 0  POLYGON ((589997.817 4524833.815, 589997.241 4...
# 1  POLYGON ((583103.656 4507601.684, 583106.215 4...
# 2  POLYGON ((591069.949 4524711.063, 591029.220 4...
# 3  POLYGON ((589297.156 4522150.813, 589144.554 4...
# 4  POLYGON ((589416.276 4520386.839, 589415.408 4...
#
#                                               buffer
# 0  POLYGON ((589911.751 4524783.056, 589908.223 4...
# 1  POLYGON ((583133.288 4507697.599, 583140.538 4...
# 2  POLYGON ((590974.905 4524676.718, 590966.700 4...
# 3  POLYGON ((589341.577 4522061.360, 589336.870 4...
# 4  POLYGON ((589258.233 4519711.282, 589258.092 4...

# %%
parks_with_buffers.crs
# Out:
# <Projected CRS: EPSG:32618>
# Name: WGS 84 / UTM zone 18N
# Axis Info [cartesian]:
# - E[east]: Easting (metre)
# - N[north]: Northing (metre)
# Area of Use:
# - name: Between 78°W and 72°W, northern hemisphere between equator and 84°N, onshore and offshore. Bahamas. Canada - Nunavut; Ontario; Quebec. Colombia. Cuba. Ecuador. Greenland. Haiti. Jamaica. Panama. Turks and Caicos Islands. United States (USA). Venezuela.
# - bounds: (-78.0, 0.0, -72.0, 84.0)
# Coordinate Operation:
# - name: UTM zone 18N
# - method: Transverse Mercator
# Datum: World Geodetic System 1984 ensemble
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %%
parks_with_buffers.explore()
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
# ...

# %% [markdown]
# #### Perform spatial join

# %%
# Perform spatial join to find cafes within the buffer zones
cafes_within_buffers = gpd.sjoin(cafe_gdf, parks_with_buffers, how='inner', predicate='within')

# %%
cafes_within_buffers.columns
# Out:
# Index(['cafe_id', 'cafe_name', 'geometry_left', 'centroid', 'index_right',
#        'park_id', 'park_name', 'geometry_right'],
#       dtype='object')

# %%
cafes_within_buffers.shape
# Out:
# (250, 8)

# %%
cafes_within_buffers.columns
# Out:
# Index(['cafe_id', 'cafe_name', 'geometry_left', 'centroid', 'index_right',
#        'park_id', 'park_name', 'geometry_right'],
#       dtype='object')

# %%
cafes_within_buffers.head()
# Out:
#     cafe_id                              cafe_name  \
# 5         6      The Landing at Pier 45 by Coffeed
# 6         7                        Ballfields Café
# 12       13                            Pier i Cafe
# 14       15                              Perk Kafe
# 17       18  55 W 40th St, New York, NY 10018, USA
#
#                                         geometry_left  \
# 5   POLYGON ((583528.543 4509602.986, 583538.036 4...
# 6   POLYGON ((586428.848 4513758.595, 586432.955 4...
# 12  POLYGON ((585347.559 4514825.557, 585348.600 4...
# 14  POLYGON ((588830.918 4515377.444, 588827.833 4...
# 17  POLYGON ((585740.083 4511890.618, 585737.818 4...
#
#                           centroid  index_right park_id  \
# 5   POINT (583533.247 4509605.924)           47   PK151
# 6   POINT (586426.997 4513764.641)          140    PK45
# 12  POINT (585352.354 4514813.577)           61   PK165
# 14  POINT (588834.197 4515372.325)           27   PK130
# ...

# %%
# count the number of cafes within each park buffer
cafes_count = cafes_within_buffers.groupby('park_id').size().reset_index(name='cafe_count')

# %%
parks_with_amenities = parks_with_buffers.merge(cafes_count, on='park_id', how='left')


parks_with_amenities['cafe_count'] = parks_with_amenities['cafe_count'].fillna(0)

print(parks_with_amenities[['park_id', 'park_name', 'cafe_count']])
# Out:
#     park_id                  park_name  cafe_count
# 0     PK101           Inwood Hill Park         0.0
# 1     PK102      Irish Hunger Memorial         3.0
# 2     PK103                 Isham Park         0.0
# 3     PK104        J. Hood Wright Park         0.0
# 4     PK105       Jackie Robinson Park         1.0
# ..      ...                        ...         ...
# 186    PK95            Highbridge Park         1.0
# 187    PK96               Hillman Park         1.0
# 188    PK97       Holcombe Rucker Park         0.0
# 189    PK98  Howard Bennett Playground         0.0
# 190    PK99          Hudson River Park         1.0
#
# [191 rows x 3 columns]

# %%
parks_with_amenities['cafe_count']=parks_with_amenities['cafe_count'].astype('int64')

# %%
parks_with_amenities.head()
# Out:
#   park_id              park_name  \
# 0   PK101       Inwood Hill Park
# 1   PK102  Irish Hunger Memorial
# 2   PK103             Isham Park
# 3   PK104    J. Hood Wright Park
# 4   PK105   Jackie Robinson Park
#
#                                             geometry  \
# 0  POLYGON ((589997.817 4524833.815, 589997.241 4...
# 1  POLYGON ((583103.656 4507601.684, 583106.215 4...
# 2  POLYGON ((591069.949 4524711.063, 591029.220 4...
# 3  POLYGON ((589297.156 4522150.813, 589144.554 4...
# 4  POLYGON ((589416.276 4520386.839, 589415.408 4...
#
#                                               buffer  cafe_count
# 0  POLYGON ((589911.751 4524783.056, 589908.223 4...           0
# 1  POLYGON ((583133.288 4507697.599, 583140.538 4...           3
# 2  POLYGON ((590974.905 4524676.718, 590966.700 4...           0
# 3  POLYGON ((589341.577 4522061.360, 589336.870 4...           0
# 4  POLYGON ((589258.233 4519711.282, 589258.092 4...           1

# %%
parks_with_amenities.dtypes
# Out:
# park_id         object
# park_name       object
# geometry      geometry
# buffer        geometry
# cafe_count       int64
# dtype: object

# %% [markdown]
# Playground

# %%
playground_gdf= gpd.read_file('playground_details.geojson')

# %%
playground_gdf.head()
# Out:
#    playground_id                                          name  \
# 0              1         120 Avenue A, New York, NY 10009, USA
# 1              2                             Battery Playscape
# 2              3  888 Main St, Roosevelt Island, NY 10044, USA
# 3              4           8 River Rd, New York, NY 10044, USA
# 4              5                           Hecksher Playground
#
#                                             geometry
# 0  POLYGON ((-73.98244 40.72698, -73.98261 40.727...
# 1  POLYGON ((-74.01458 40.70199, -74.01460 40.701...
# 2  POLYGON ((-73.94480 40.76892, -73.94485 40.768...
# 3  POLYGON ((-73.94846 40.76484, -73.94835 40.764...
# 4  POLYGON ((-73.97786 40.76832, -73.97779 40.768...

# %%
playground_gdf.crs
# Out:
# <Geographic 2D CRS: EPSG:4326>
# Name: WGS 84
# Axis Info [ellipsoidal]:
# - Lat[north]: Geodetic latitude (degree)
# - Lon[east]: Geodetic longitude (degree)
# Area of Use:
# - undefined
# Datum: World Geodetic System 1984
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %%
playground_gdf=playground_gdf.to_crs(epsg=32618)

# %%
playground_gdf['centroid']=playground_gdf.centroid

# %%
playground_gdf= playground_gdf.set_geometry('centroid')

# %%
playground_gdf.geometry.name
# Out:
# 'centroid'

# %%
playground_gdf= playground_gdf.rename({'name':'playground_name'},axis=1)

# %%
playgrounds_within_parks = gpd.sjoin(playground_gdf, unique_parks_gdf, how='inner', predicate='within')

# %%
playgrounds_within_parks.shape
# Out:
# (151, 8)

# %%
playgrounds_within_parks.head()
# Out:
#     playground_id                        playground_name  \
# 0               1  120 Avenue A, New York, NY 10009, USA
# 1               2                      Battery Playscape
# 4               5                    Hecksher Playground
# 5               6  10-23 FDR Dr, New York, NY 10009, USA
# 13             14           Saint Vartan Park playground
#
#                                              geometry  \
# 0   POLYGON ((585931.365 4508947.897, 585916.997 4...
# 1   POLYGON ((583247.950 4506142.985, 583246.534 4...
# 4   POLYGON ((586264.623 4513540.907, 586270.540 4...
# 5   POLYGON ((586750.235 4508681.953, 586739.688 4...
# 13  POLYGON ((586670.651 4510966.781, 586653.057 4...
#
#                           centroid  index_right park_id  \
# 0   POINT (585915.791 4508933.971)           99   PK202
# 1   POINT (583269.807 4506135.028)          127    PK31
# 4   POINT (586302.340 4513580.128)          140    PK45
# 5   POINT (586764.358 4508650.742)           12   PK112
# ...

# %%
playground_counts=playgrounds_within_parks.groupby('park_id').size().reset_index(name='playground_count')

# %%
playground_counts
# Out:
#    park_id  playground_count
# 0    PK101                 3
# 1    PK104                 1
# 2    PK105                 1
# 3    PK107                 2
# 4    PK108                 1
# ..     ...               ...
# 70    PK80                 3
# 71    PK88                 1
# 72    PK90                 3
# 73    PK95                 5
# 74    PK99                 1
#
# [75 rows x 2 columns]

# %%
parks_with_amenities= parks_with_amenities.merge(playground_counts,how='left',on='park_id')

# %%
parks_with_amenities['playground_count']= parks_with_amenities['playground_count'].fillna('0')

# %%
parks_with_amenities['playground_count']= parks_with_amenities['playground_count'].astype('int64')

# %%
parks_with_amenities.shape
# Out:
# (191, 6)

# %% [markdown]
# Toilets

# %%
toilets_gdf_dir= gpd.read_file('dir_toilets_geocode.geojson')

# %%
toilets_gdf_OSM=gpd.read_file('toiletsOSM_cleaned.geojson')

# %%
toilets_gdf_OSM.head()
# Out:
#                            name  \
# 0                          None
# 1                          None
# 2  Washington Square Park House
# 3                          None
# 4                          None
#
#                                             geometry
# 0  POLYGON ((-73.94618 40.84715, -73.94617 40.847...
# 1  POLYGON ((-73.95904 40.75327, -73.95908 40.753...
# 2  POLYGON ((-73.99834 40.73073, -73.99829 40.730...
# 3  POLYGON ((-73.98561 40.72422, -73.98557 40.724...
# 4  POLYGON ((-73.98951 40.73632, -73.98959 40.736...

# %%
toilets_gdf_dir.head()
# Out:
#                             Name  \
# 0  Alexander Hamilton Playground
# 1        Alice Kornegay Triangle
# 2              Annunciation Park
# 3                     Asser Levy
# 4             Audubon Playground
#
#                                         Location Open Year-Round  \
# 0   Hamilton Place, West 140 to West 141 streets             Yes
# 1  Lexington Avenue, East 128 & East 129 streets             Yes
# 2             Convent and Amsterdam Av, W 135 St
# 3          Asser Levy Place & East 24-25 streets             Yes
# 4               West 170 Street & Audubon Avenue             Yes
#
#   Handicap Accessible    Borough Comments   Latitude  Longitude  \
# 0                      Manhattan           40.822658 -73.951304
# 1                      Manhattan           38.890657 -94.514549
# 2                 Yes  Manhattan           40.818939 -73.952226
# 3                      Manhattan           40.736160 -73.975658
# ...

# %%
toilets_gdf_OSM.crs
# Out:
# <Geographic 2D CRS: EPSG:4326>
# Name: WGS 84
# Axis Info [ellipsoidal]:
# - Lat[north]: Geodetic latitude (degree)
# - Lon[east]: Geodetic longitude (degree)
# Area of Use:
# - undefined
# Datum: World Geodetic System 1984
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %%
toilets_gdf_dir.shape
# Out:
# (120, 9)

# %%
toilets_gdf_OSM.shape
# Out:
# (184, 2)

# %%
toilets_gdf_dir.to_crs(epsg=32618,inplace=True)

# %%
toilets_gdf_dir.columns
# Out:
# Index(['Name', 'Location', 'Open Year-Round', 'Handicap Accessible', 'Borough',
#        'Comments', 'Latitude', 'Longitude', 'geometry'],
#       dtype='object')

# %%
toilets_gdf_dir=toilets_gdf_dir[['Name', 'Location','Handicap Accessible', 'geometry']]

# %%
toilets_gdf_dir['centroid']=toilets_gdf_dir.centroid

# %%
toilets_gdf_dir.set_geometry('centroid',inplace=True)

# %%
toilets_gdf_dir=toilets_gdf_dir.drop(columns='geometry')

# %%
toilets_gdf_dir
# Out:
#                                           Name  \
# 0                Alexander Hamilton Playground
# 1                      Alice Kornegay Triangle
# 2                            Annunciation Park
# 3                                   Asser Levy
# 4                           Audubon Playground
# ..                                         ...
# 115                          Union Square Park
# 116                         Vesuvio Playground
# 117                                Wagner Pool
# 118        Washington Square Park Western Half
# 119  West 59th Street Recreation Center & Pool
#
#                                               Location Handicap Accessible  \
# 0         Hamilton Place, West 140 to West 141 streets
# 1        Lexington Avenue, East 128 & East 129 streets
# 2                   Convent and Amsterdam Av, W 135 St                 Yes
# 3                Asser Levy Place & East 24-25 streets
# 4                     West 170 Street & Audubon Avenue
# ...

# %%
toilets_gdf_OSM.to_crs(epsg=32618,inplace=True)

# %%
toilets_gdf_OSM['centroid']=toilets_gdf_OSM.centroid

# %%
toilets_gdf_OSM=toilets_gdf_OSM.rename(columns={'name':'Name'})

# %%
toilets_gdf_dir.is_valid.value_counts()
# Out:
# True    120
# Name: count, dtype: int64

# %%
toilets_gdf_OSM.is_valid.value_counts()
# Out:
# True    184
# Name: count, dtype: int64

# %%
import pandas as pd

# %%
toilets_gdf_OSM=toilets_gdf_OSM.set_geometry('centroid')

# %%
toilets_gdf_OSM.drop(columns='geometry',inplace=True)

# %%
merged_toilets=pd.concat([toilets_gdf_dir,toilets_gdf_OSM],ignore_index=True)

# %%
merged_toilets['toilet_id']=merged_toilets.index+1

# %%
merged_toilets.columns
# Out:
# Index(['Name', 'Location', 'Handicap Accessible', 'centroid', 'toilet_id'], dtype='object')

# %%
merged_toilets= merged_toilets[['toilet_id','Name', 'Location', 'Handicap Accessible', 'centroid']]

# %%
merged_toilets.is_valid.value_counts()
# Out:
# True    304
# Name: count, dtype: int64

# %%
merged_toilets.shape
# Out:
# (304, 5)

# %%
merged_toilets=merged_toilets.fillna('unknown')

# %%
merged_toilets['Handicap Accessible']=merged_toilets['Handicap Accessible'].replace('','No')

# %%
merged_toilets['Handicap Accessible']=merged_toilets['Handicap Accessible'].replace('unknown','No')

# %%
merged_toilets.isnull().sum()
# Out:
# toilet_id              0
# Name                   0
# Location               0
# Handicap Accessible    0
# centroid               0
# dtype: int64

# %%
merged_toilets=merged_toilets.to_crs(epsg=4326)

# %% [markdown]
# Geocode the toilets

# %% [markdown]
# import requests
#
# def reverse_geocode(lat,lng,api_key):
#     geocode_url= 'https://maps.googleapis.com/maps/api/geocode/json'
#
#     params= {'latlng':f'{lat},{lng}', 'key': api_key}
#
#     response=requests.get(geocode_url,params=params)
#     outcome=response.json()
#
#     if outcome['status'] =='OK':
#         final_outcome=outcome['results'][0]['formatted_address']
#         return final_outcome
#     else:
#         raise Exception(f"Error in geocoding request: {outcome['status']}")

# %% [markdown]
# api_key= 'AIzaSyAvr9o38Xk159Uh4BTvDkKrKLvO7t9VvxU'

# %% [markdown]
# for index,row in merged_toilets.iterrows():
#     if row['Location']=='unknown':
#         try:
#             lat=row['centroid'].y
#             lng=row['centroid'].x
#             name= reverse_geocode(lat,lng,api_key)
#             merged_toilets.at[index, 'Location'] =name
#             print(f'Success geocoding location {row['Location']}')
#         except Exception as e:
#             print(f'Error geocoding address at {row['Location']} :{e}')

# %%
merged_toilets=merged_toilets.to_crs(epsg=32618)

# %%
toilets_within_parks=gpd.sjoin(merged_toilets,unique_parks_gdf,how='inner',predicate='within')

# %%
toilets_within_parks
# Out:
#      toilet_id                                           Name  \
# 3            4                                     Asser Levy
# 16          17                Central Park (Bethesda Terrace)
# 19          20            Central Park (Heckscher Playground)
# 23          24  Central Park (North Meadow Recreation Center)
# 24          25                          Central Park (Ramble)
# ..         ...                                            ...
# 293        294                                        unknown
# 294        295                                        unknown
# 298        299                                        unknown
# 301        302                                        unknown
# 302        303                                        unknown
#
#                                   Location Handicap Accessible  \
# 3    Asser Levy Place & East 24-25 streets                  No
# 16                                                          No
# ...

# %%
toilets_within_parks.shape
# Out:
# (144, 9)

# %%
toilets_within_parks.head()
# Out:
#     toilet_id                                           Name  \
# 3           4                                     Asser Levy
# 16         17                Central Park (Bethesda Terrace)
# 19         20            Central Park (Heckscher Playground)
# 23         24  Central Park (North Meadow Recreation Center)
# 24         25                          Central Park (Ramble)
#
#                                  Location Handicap Accessible  \
# 3   Asser Levy Place & East 24-25 streets                  No
# 16                                                         No
# 19           62 ST, BET WEST & CENTER DRS                  No
# 23                Mid-park at 97th Street                 Yes
# 24                           Central Park                  No
#
#                           centroid  index_right park_id  \
# 3   POINT (586492.019 4509973.576)          126    PK30
# 16  POINT (586839.050 4514173.481)          140    PK45
# ...

# %%
toilets_counts=toilets_within_parks.groupby('park_id').size().reset_index(name='toilet_count')

# %%
toilets_handicap_yes_info=toilets_within_parks[toilets_within_parks['Handicap Accessible']=='Yes']

# %%
toilets_handicap_yes_info
# Out:
#      toilet_id                                           Name  \
# 23          24  Central Park (North Meadow Recreation Center)
# 25          26   Central Park (Sheep Meadow, Mineral Springs)
# 30          31                    Central Park (Wollman Rink)
# 31          32         Central Park Delacorte Comfort Station
# 38          39                           De Witt Clinton Park
# 88          89                          Riverside Park (Café)
# 110        111                                St. Vartan Park
# 114        115                           Tompkins Square Park
#
#                                               Location Handicap Accessible  \
# 23                             Mid-park at 97th Street                 Yes
# 25                             Mid-park at 69th Street                 Yes
# 30   Center Drive to East Drive (including Gapstow ...                 Yes
# 31                             Mid-Park at 80th Street                 Yes
# ...

# %%
handicap_counts=toilets_handicap_yes_info.groupby('park_id')['Handicap Accessible'].size().reset_index(name='handicap_access_count')

# %%
toilets_counts
# Out:
#    park_id  toilet_count
# 0    PK101             3
# 1    PK105             2
# 2    PK106             1
# 3    PK108             1
# 4    PK112             4
# 5    PK117             1
# 6    PK121             1
# 7    PK127             1
# 8    PK129             1
# 9    PK131             2
# 10   PK134             1
# 11   PK137             2
# 12   PK153             1
# 13   PK157             2
# 14   PK160             4
# 15   PK162             1
# 16   PK163             1
# 17   PK164            12
# 18   PK165             1
# 19   PK167             2
# 20   PK172             1
# 21   PK173             2
# 22   PK176             6
# 23   PK178             2
# 24   PK181             1
# 25   PK185             1
# 26   PK186             2
# 27   PK194             1
# 28   PK197             2
# 29   PK202             2
# 30   PK205             1
# 31   PK207             2
# 32   PK213             2
# 33   PK214             1
# 34   PK216             2
# 35   PK217             1
# ...

# %%
handicap_counts
# Out:
#   park_id  handicap_access_count
# 0   PK173                      1
# 1   PK202                      1
# 2    PK45                      4
# 3    PK64                      1
# 4    PK80                      1

# %%
toilet_handicap_counts= toilets_counts.merge(handicap_counts,how='left',on='park_id')

# %%
toilet_handicap_counts
# Out:
#    park_id  toilet_count  handicap_access_count
# 0    PK101             3                    NaN
# 1    PK105             2                    NaN
# 2    PK106             1                    NaN
# 3    PK108             1                    NaN
# 4    PK112             4                    NaN
# 5    PK117             1                    NaN
# 6    PK121             1                    NaN
# 7    PK127             1                    NaN
# 8    PK129             1                    NaN
# 9    PK131             2                    NaN
# 10   PK134             1                    NaN
# 11   PK137             2                    NaN
# 12   PK153             1                    NaN
# 13   PK157             2                    NaN
# 14   PK160             4                    NaN
# 15   PK162             1                    NaN
# 16   PK163             1                    NaN
# 17   PK164            12                    NaN
# 18   PK165             1                    NaN
# ...

# %%
toilet_handicap_counts.columns
# Out:
# Index(['park_id', 'toilet_count', 'handicap_access_count'], dtype='object')

# %%
toilet_handicap_counts=toilet_handicap_counts.rename(columns={'handicap_access_count':'toilet_handicap_access_count'})

# %%
toilet_handicap_counts['toilet_handicap_access_count']= toilet_handicap_counts['toilet_handicap_access_count'].fillna('No')

# %%
toilet_handicap_counts['toilet_handicap_access_count']= toilet_handicap_counts['toilet_handicap_access_count'].replace('No','0')

# %%
toilet_handicap_counts['toilet_handicap_access_count']= toilet_handicap_counts['toilet_handicap_access_count'].replace('Yes','1')

# %%
toilet_handicap_counts['toilet_handicap_access_count']= toilet_handicap_counts['toilet_handicap_access_count'].astype('int64')

# %%
toilet_handicap_counts
# Out:
#    park_id  toilet_count  toilet_handicap_access_count
# 0    PK101             3                             0
# 1    PK105             2                             0
# 2    PK106             1                             0
# 3    PK108             1                             0
# 4    PK112             4                             0
# 5    PK117             1                             0
# 6    PK121             1                             0
# 7    PK127             1                             0
# 8    PK129             1                             0
# 9    PK131             2                             0
# 10   PK134             1                             0
# 11   PK137             2                             0
# 12   PK153             1                             0
# 13   PK157             2                             0
# 14   PK160             4                             0
# 15   PK162             1                             0
# ...

# %%
parks_with_amenities=parks_with_amenities.merge(toilet_handicap_counts, how='left',on='park_id')

# %%
parks_with_amenities
# Out:
#     park_id                  park_name  \
# 0     PK101           Inwood Hill Park
# 1     PK102      Irish Hunger Memorial
# 2     PK103                 Isham Park
# 3     PK104        J. Hood Wright Park
# 4     PK105       Jackie Robinson Park
# ..      ...                        ...
# 186    PK95            Highbridge Park
# 187    PK96               Hillman Park
# 188    PK97       Holcombe Rucker Park
# 189    PK98  Howard Bennett Playground
# 190    PK99          Hudson River Park
#
#                                               geometry  \
# 0    POLYGON ((589997.817 4524833.815, 589997.241 4...
# 1    POLYGON ((583103.656 4507601.684, 583106.215 4...
# 2    POLYGON ((591069.949 4524711.063, 591029.220 4...
# 3    POLYGON ((589297.156 4522150.813, 589144.554 4...
# 4    POLYGON ((589416.276 4520386.839, 589415.408 4...
# ..                                                 ...
# 186  MULTIPOLYGON (((589292.666 4520521.927, 589333...
# ...

# %%
parks_with_amenities['toilet_count']=parks_with_amenities['toilet_count'].fillna(0)

# %%
parks_with_amenities['toilet_count']=parks_with_amenities['toilet_count'].astype('int64')

# %%
parks_with_amenities['toilet_handicap_access_count']=parks_with_amenities['toilet_handicap_access_count'].fillna(0)

# %%
parks_with_amenities['toilet_handicap_access_count']=parks_with_amenities['toilet_handicap_access_count'].astype('int64')

# %%
parks_with_amenities.head()
# Out:
#   park_id              park_name  \
# 0   PK101       Inwood Hill Park
# 1   PK102  Irish Hunger Memorial
# 2   PK103             Isham Park
# 3   PK104    J. Hood Wright Park
# 4   PK105   Jackie Robinson Park
#
#                                             geometry  \
# 0  POLYGON ((589997.817 4524833.815, 589997.241 4...
# 1  POLYGON ((583103.656 4507601.684, 583106.215 4...
# 2  POLYGON ((591069.949 4524711.063, 591029.220 4...
# 3  POLYGON ((589297.156 4522150.813, 589144.554 4...
# 4  POLYGON ((589416.276 4520386.839, 589415.408 4...
#
#                                               buffer  cafe_count  \
# 0  POLYGON ((589911.751 4524783.056, 589908.223 4...           0
# 1  POLYGON ((583133.288 4507697.599, 583140.538 4...           3
# 2  POLYGON ((590974.905 4524676.718, 590966.700 4...           0
# 3  POLYGON ((589341.577 4522061.360, 589336.870 4...           0
# 4  POLYGON ((589258.233 4519711.282, 589258.092 4...           1
#
# ...

# %%
parks_with_amenities.shape
# Out:
# (191, 8)

# %%
parks_with_amenities_indv=parks_with_amenities[parks_with_amenities['park_id']=='PK80']
parks_with_amenities_indv
# Out:
#     park_id             park_name  \
# 173    PK80  Fort Washington Park
#
#                                               geometry  \
# 173  POLYGON ((588575.779 4521230.996, 588578.236 4...
#
#                                                 buffer  cafe_count  \
# 173  POLYGON ((588477.809 4521251.040, 588479.974 4...           1
#
#      playground_count  toilet_count  toilet_handicap_access_count
# 173                 3             6                             1

# %% [markdown]
# Restaurants

# %%
restaurants_gdf=gpd.read_file('restaurantOSM_cleaned.geojson')

# %%
restaurants_gdf.shape
# Out:
# (3213, 3)

# %%
restaurants_gdf.head()
# Out:
#    restaurant_id      restaurant_name  \
# 0              1       Loeb Boathouse
# 1              2  Tavern on the Green
# 2              3              Sofrito
# 3              4        Cotta Osteria
# 4              5              Fornino
#
#                                             geometry
# 0  POLYGON ((-73.96861 40.77551, -73.96862 40.775...
# 1  MULTIPOLYGON (((-73.97742 40.77239, -73.97745 ...
# 2  POLYGON ((-73.95554 40.82742, -73.95548 40.827...
# 3  POLYGON ((-73.97273 40.78543, -73.97266 40.785...
# 4  POLYGON ((-74.00161 40.69281, -74.00152 40.692...

# %%
restaurants_gdf=restaurants_gdf.to_crs(epsg=32618)

# %%
restaurants_gdf['centroid']=restaurants_gdf.centroid

# %%
restaurants_gdf=restaurants_gdf.set_geometry('centroid')

# %%
restaurants_gdf.geometry.name
# Out:
# 'centroid'

# %%
restaurants_within_parks=gpd.sjoin(restaurants_gdf,parks_with_buffers,how='inner',predicate='within')

# %%
restaurants_within_parks.head()
# Out:
#    restaurant_id      restaurant_name  \
# 0              1       Loeb Boathouse
# 1              2  Tavern on the Green
# 2              3              Sofrito
# 2              3              Sofrito
# 7              8              Cocoron
#
#                                        geometry_left  \
# 0  POLYGON ((587035.865 4514348.800, 587035.280 4...
# 1  MULTIPOLYGON (((586296.640 4513994.165, 586294...
# 2  POLYGON ((588070.146 4520123.673, 588075.737 4...
# 2  POLYGON ((588070.146 4520123.673, 588075.737 4...
# 7  POLYGON ((585044.122 4508189.207, 585049.459 4...
#
#                          centroid  index_right park_id  \
# 0  POINT (587022.063 4514330.876)          140    PK45
# 1  POINT (586284.271 4513971.057)          140    PK45
# 2  POINT (588088.588 4520111.372)           59   PK163
# 2  POINT (588088.588 4520111.372)           60   PK164
# 7  POINT (585043.737 4508197.424)           72   PK176
#
# ...

# %%
restaurant_counts=restaurants_within_parks.groupby('park_id').size().reset_index(name='restaurant_count')

# %%
restaurant_counts.head()
# Out:
#   park_id  restaurant_count
# 0   PK101                 5
# 1   PK102                 4
# 2   PK103                 2
# 3   PK105                 2
# 4   PK106                 2

# %%
parks_with_amenities=parks_with_amenities.merge(restaurant_counts,how='left',on='park_id')

# %%
parks_with_amenities.head()
# Out:
#   park_id              park_name  \
# 0   PK101       Inwood Hill Park
# 1   PK102  Irish Hunger Memorial
# 2   PK103             Isham Park
# 3   PK104    J. Hood Wright Park
# 4   PK105   Jackie Robinson Park
#
#                                             geometry  \
# 0  POLYGON ((589997.817 4524833.815, 589997.241 4...
# 1  POLYGON ((583103.656 4507601.684, 583106.215 4...
# 2  POLYGON ((591069.949 4524711.063, 591029.220 4...
# 3  POLYGON ((589297.156 4522150.813, 589144.554 4...
# 4  POLYGON ((589416.276 4520386.839, 589415.408 4...
#
#                                               buffer  cafe_count  \
# 0  POLYGON ((589911.751 4524783.056, 589908.223 4...           0
# 1  POLYGON ((583133.288 4507697.599, 583140.538 4...           3
# 2  POLYGON ((590974.905 4524676.718, 590966.700 4...           0
# 3  POLYGON ((589341.577 4522061.360, 589336.870 4...           0
# 4  POLYGON ((589258.233 4519711.282, 589258.092 4...           1
#
# ...

# %%
parks_with_amenities['restaurant_count']=parks_with_amenities['restaurant_count'].fillna(0)

# %%
parks_with_amenities.head()
# Out:
#   park_id              park_name  \
# 0   PK101       Inwood Hill Park
# 1   PK102  Irish Hunger Memorial
# 2   PK103             Isham Park
# 3   PK104    J. Hood Wright Park
# 4   PK105   Jackie Robinson Park
#
#                                             geometry  \
# 0  POLYGON ((589997.817 4524833.815, 589997.241 4...
# 1  POLYGON ((583103.656 4507601.684, 583106.215 4...
# 2  POLYGON ((591069.949 4524711.063, 591029.220 4...
# 3  POLYGON ((589297.156 4522150.813, 589144.554 4...
# 4  POLYGON ((589416.276 4520386.839, 589415.408 4...
#
#                                               buffer  cafe_count  \
# 0  POLYGON ((589911.751 4524783.056, 589908.223 4...           0
# 1  POLYGON ((583133.288 4507697.599, 583140.538 4...           3
# 2  POLYGON ((590974.905 4524676.718, 590966.700 4...           0
# 3  POLYGON ((589341.577 4522061.360, 589336.870 4...           0
# 4  POLYGON ((589258.233 4519711.282, 589258.092 4...           1
#
# ...

# %%
parks_with_amenities['restaurant_count']=parks_with_amenities['restaurant_count'].astype('int64')

# %% [markdown]
# Shelter

# %%
shelter_gdf=gpd.read_file('shelter_cleaned.geojson')

# %%
shelter_gdf_details=shelter_gdf[['id','geometry']]

# %%
shelter_gdf_details=shelter_gdf_details.to_crs(epsg=32618)

# %%
shelter_gdf_details['centroid']=shelter_gdf_details.centroid

# %%
shelter_gdf_details=shelter_gdf_details.set_geometry('centroid')

# %%
shelter_gdf_details.geometry.name
# Out:
# 'centroid'

# %%
shelter_within_parks=gpd.sjoin(shelter_gdf_details,unique_parks_gdf,how='inner',predicate='within')

# %%
shelter_within_parks.head()
# Out:
#    id                                           geometry  \
# 2   3  POLYGON ((587394.597 4518577.734, 587402.031 4...
# 3   4  POLYGON ((585390.666 4507655.734, 585393.148 4...
# 4   5  POLYGON ((590056.380 4523965.360, 590059.519 4...
# 5   6  POLYGON ((584176.285 4506456.098, 584179.266 4...
# 6   7  POLYGON ((586388.583 4513384.878, 586389.095 4...
#
#                          centroid  index_right park_id  \
# 2  POINT (587394.176 4518588.869)           60   PK164
# 3  POINT (585388.848 4507659.848)           76   PK180
# 4  POINT (590054.201 4523970.581)          172    PK79
# 5  POINT (584189.225 4506458.005)          167    PK73
# 6  POINT (586383.791 4513387.246)          140    PK45
#
#                                         park_name  \
# 2                                  Riverside Park
# 3  Seward Park High School - Community Playground
# 4                                 Fort Tryon Park
# 5                 East River Waterfront Esplanade
# ...

# %%
shelter_counts=shelter_within_parks.groupby('park_id').size().reset_index(name='shelter_count')

# %%
parks_with_amenities=parks_with_amenities.merge(shelter_counts,how='left',on='park_id')

# %%
parks_with_amenities['shelter_count']=parks_with_amenities['shelter_count'].fillna(0)

# %%
parks_with_amenities['shelter_count']=parks_with_amenities['shelter_count'].astype('int64')
parks_with_amenities
# Out:
#     park_id                  park_name  \
# 0     PK101           Inwood Hill Park
# 1     PK102      Irish Hunger Memorial
# 2     PK103                 Isham Park
# 3     PK104        J. Hood Wright Park
# 4     PK105       Jackie Robinson Park
# ..      ...                        ...
# 186    PK95            Highbridge Park
# 187    PK96               Hillman Park
# 188    PK97       Holcombe Rucker Park
# 189    PK98  Howard Bennett Playground
# 190    PK99          Hudson River Park
#
#                                               geometry  \
# 0    POLYGON ((589997.817 4524833.815, 589997.241 4...
# 1    POLYGON ((583103.656 4507601.684, 583106.215 4...
# 2    POLYGON ((591069.949 4524711.063, 591029.220 4...
# 3    POLYGON ((589297.156 4522150.813, 589144.554 4...
# 4    POLYGON ((589416.276 4520386.839, 589415.408 4...
# ..                                                 ...
# 186  MULTIPOLYGON (((589292.666 4520521.927, 589333...
# ...

# %% [markdown]
# Drinking Water

# %%
drinking_water_gdf=gpd.read_file('drinking_water_cleaned.geojson')

# %%
drinking_water_gdf.head()
# Out:
#    drinking_water_id                    geometry
# 0                  1  POINT (-73.95821 40.79943)
# 1                  2  POINT (-73.95537 40.79287)
# 2                  3  POINT (-73.95563 40.79220)
# 3                  4  POINT (-73.99601 40.72172)
# 4                  5  POINT (-73.93594 40.83813)

# %%
drinking_water_gdf= drinking_water_gdf.to_crs(epsg=32618)

# %%
drinking_water_gdf['centroid']=drinking_water_gdf.centroid

# %%
drinking_water_gdf= drinking_water_gdf.set_geometry('centroid')

# %%
drinking_water_within_parks=gpd.sjoin(drinking_water_gdf,unique_parks_gdf,how='inner',predicate='within')

# %%
drinking_water_within_parks.head()
# Out:
#    drinking_water_id                        geometry  \
# 0                  1  POINT (587882.051 4517014.697)
# 1                  2  POINT (588130.245 4516289.288)
# 2                  3  POINT (588109.412 4516214.187)
# 4                  5  POINT (589708.016 4521332.593)
# 5                  6  POINT (590624.296 4523526.020)
#
#                          centroid  index_right park_id        park_name  \
# 0  POINT (587882.051 4517014.697)          140    PK45     Central Park
# 1  POINT (588130.245 4516289.288)          140    PK45     Central Park
# 2  POINT (588109.412 4516214.187)          140    PK45     Central Park
# 4  POINT (589708.016 4521332.593)          186    PK95  Highbridge Park
# 5  POINT (590624.296 4523526.020)          186    PK95  Highbridge Park
#
#                                               buffer
# 0  POLYGON ((585881.817 4513497.588, 585880.086 4...
# 1  POLYGON ((585881.817 4513497.588, 585880.086 4...
# ...

# %%
drinking_water_counts=drinking_water_within_parks.groupby('park_id').size().reset_index(name='drinking_water_count')

# %%
parks_with_amenities=parks_with_amenities.merge(drinking_water_counts,how='left',on='park_id')

# %%
parks_with_amenities['drinking_water_count']=parks_with_amenities['drinking_water_count'].fillna(0)

# %%
parks_with_amenities['drinking_water_count']=parks_with_amenities['drinking_water_count'].astype('int64')

# %%
parks_with_amenities.head()
# Out:
#   park_id              park_name  \
# 0   PK101       Inwood Hill Park
# 1   PK102  Irish Hunger Memorial
# 2   PK103             Isham Park
# 3   PK104    J. Hood Wright Park
# 4   PK105   Jackie Robinson Park
#
#                                             geometry  \
# 0  POLYGON ((589997.817 4524833.815, 589997.241 4...
# 1  POLYGON ((583103.656 4507601.684, 583106.215 4...
# 2  POLYGON ((591069.949 4524711.063, 591029.220 4...
# 3  POLYGON ((589297.156 4522150.813, 589144.554 4...
# 4  POLYGON ((589416.276 4520386.839, 589415.408 4...
#
#                                               buffer  cafe_count  \
# 0  POLYGON ((589911.751 4524783.056, 589908.223 4...           0
# 1  POLYGON ((583133.288 4507697.599, 583140.538 4...           3
# 2  POLYGON ((590974.905 4524676.718, 590966.700 4...           0
# 3  POLYGON ((589341.577 4522061.360, 589336.870 4...           0
# 4  POLYGON ((589258.233 4519711.282, 589258.092 4...           1
#
# ...

# %% [markdown]
# Bar

# %%
bar_gdf=gpd.read_file('bar_cleaned.geojson')

# %%
type(bar_gdf)
# Out:
# geopandas.geodataframe.GeoDataFrame

# %%
bar_gdf['bar_id']=bar_gdf.index +1

# %%
bar_gdf= bar_gdf.to_crs(epsg=32618)

# %%
bar_gdf['centroid']=bar_gdf.centroid

# %%
bar_gdf=bar_gdf.set_geometry('centroid')

# %%
bar_gdf.geometry.name
# Out:
# 'centroid'

# %%
bar_within_parks=gpd.sjoin(bar_gdf,parks_with_buffers,how='inner',predicate='within')

# %%
bar_within_parks
# Out:
#      bar_id                bar_name  \
# 11       12             Cotton Club
# 11       12             Cotton Club
# 13       14      Merrion Square Pub
# 24       25                 Ear Inn
# 25       26                  Barfly
# ..      ...                     ...
# 566     567  Gebhard's Beer Culture
# 569     570               NºBetween
# 569     570               NºBetween
# 571     572       House of Machines
# 574     575             Proletariat
#
#                                          geometry_left  \
# 11   POLYGON ((587692.282 4519016.507, 587692.957 4...
# 11   POLYGON ((587692.282 4519016.507, 587692.957 4...
# 13   POLYGON ((588839.347 4515262.291, 588821.026 4...
# 24                      POINT (583648.395 4508802.223)
# 25                      POINT (585734.439 4510073.022)
# ..                                                 ...
# 566                     POINT (585806.241 4514727.176)
# 569                     POINT (583840.314 4510672.253)
# ...

# %%
bar_counts=bar_within_parks.groupby('park_id').size().reset_index(name='bar_count')

# %%
parks_with_amenities=parks_with_amenities.merge(bar_counts,how='left',on='park_id')

# %%
parks_with_amenities['bar_count']=parks_with_amenities['bar_count'].fillna(0)

# %%
parks_with_amenities['bar_count']=parks_with_amenities['bar_count'].astype('int64')

# %%
parks_with_amenities.shape
# Out:
# (191, 12)

# %% [markdown]
# Bench

# %%
bench_gdf=gpd.read_file('bench_cleaned.geojson')

# %%
bench_gdf= bench_gdf.to_crs(epsg=32618)

# %%
bench_gdf['centroid']=bench_gdf.centroid

# %%
bench_gdf=bench_gdf.set_geometry('centroid')

# %%
bench_gdf.shape
# Out:
# (5784, 3)

# %%
bench_within_parks=gpd.sjoin(bench_gdf,unique_parks_gdf,how='inner',predicate='within')

# %%
bench_counts=bench_within_parks.groupby('park_id').size().reset_index(name='bench_count')

# %%
parks_with_amenities=parks_with_amenities.merge(bench_counts,how='left',on='park_id')

# %%
parks_with_amenities['bench_count']=parks_with_amenities['bench_count'].fillna(0)

# %%
parks_with_amenities['bench_count']=parks_with_amenities['bench_count'].astype('int64')

# %%
parks_with_amenities['bench_count'].value_counts()
# Out:
# bench_count
# 0      106
# 5        7
# 2        4
# 3        4
# 8        4
# 19       3
# 11       3
# 29       3
# 6        3
# 81       2
# 47       2
# 12       2
# 30       2
# 17       2
# 24       2
# 15       2
# 7        2
# 55       1
# 20       1
# 36       1
# 96       1
# 402      1
# 16       1
# 22       1
# 23       1
# 63       1
# 202      1
# 123      1
# 162      1
# 54       1
# 41       1
# 27       1
# 171      1
# 21       1
# 35       1
# 26       1
# 65       1
# 32       1
# 4        1
# 37       1
# 33       1
# 106      1
# 58       1
# 18       1
# 13       1
# 44       1
# 34       1
# 73       1
# 56       1
# 53       1
# 43       1
# 50       1
# 42       1
# 71       1
# 128      1
# Name: count, dtype: int64

# %% [markdown]
# Garden

# %%
garden_gdf=gpd.read_file('garden_cleaned.geojson')

# %%
garden_gdf.head()
# Out:
#    garden_id                                           geometry
# 0          1  MULTIPOLYGON (((-73.93347 40.78810, -73.93360 ...
# 1          2  POLYGON ((-74.01319 40.70985, -74.01306 40.709...
# 2          3  POLYGON ((-74.01334 40.70987, -74.01331 40.709...
# 3          4  MULTIPOLYGON (((-73.99014 40.77391, -73.99014 ...
# 4          5  POLYGON ((-73.99953 40.74948, -73.99954 40.749...

# %%
garden_gdf= garden_gdf.to_crs(epsg=32618)

# %%
garden_gdf['centroid']=garden_gdf.centroid

# %%
garden_gdf=garden_gdf.set_geometry('centroid')

# %%
garden_within_parks=gpd.sjoin(garden_gdf,unique_parks_gdf,how='inner',predicate='within')

# %%
garden_within_parks
# Out:
#       garden_id                                           geometry  \
# 0             1  MULTIPOLYGON (((589984.088 4515782.095, 589973...
# 1             2  POLYGON ((583356.025 4507016.773, 583366.485 4...
# 2             3  POLYGON ((583342.787 4507019.011, 583345.664 4...
# 4             5  POLYGON ((584459.405 4511428.845, 584458.485 4...
# 5             6  MULTIPOLYGON (((583153.077 4506098.246, 583154...
# ...         ...                                                ...
# 4282       4283  POLYGON ((586843.877 4517345.586, 586836.704 4...
# 4283       4284  POLYGON ((588837.158 4522292.473, 588840.062 4...
# 4288       4289                     POINT (586766.000 4513507.308)
# 4289       4290                     POINT (586744.524 4513436.912)
# 4290       4291                     POINT (586719.202 4513539.911)
#
#                             centroid  index_right park_id  \
# 0     POINT (590043.018 4515868.059)          111   PK216
# ...

# %%
garden_counts=garden_within_parks.groupby('park_id').size().reset_index(name='garden_count')

# %%
parks_with_amenities=parks_with_amenities.merge(garden_counts,how='left',on='park_id')

# %%
parks_with_amenities['garden_count']= parks_with_amenities['garden_count'].fillna(0)

# %%
parks_with_amenities['garden_count']= parks_with_amenities['garden_count'].astype('int64')

# %%
parks_with_amenities['garden_count'].value_counts()
# Out:
# garden_count
# 0      119
# 1        7
# 2        6
# 12       5
# 6        5
# 4        4
# 17       3
# 55       3
# 5        3
# 3        3
# 7        3
# 16       2
# 25       2
# 9        2
# 11       2
# 28       2
# 38       1
# 35       1
# 33       1
# 26       1
# 13       1
# 8        1
# 51       1
# 59       1
# 83       1
# 22       1
# 14       1
# 132      1
# 15       1
# 37       1
# 31       1
# 50       1
# 184      1
# 54       1
# 19       1
# 53       1
# Name: count, dtype: int64

# %%
parks_with_amenities.shape
# Out:
# (191, 14)

# %% [markdown]
# Fountain

# %%
fountain_gdf=gpd.read_file('fountain_cleaned.geojson')

# %%
fountain_gdf.head()
# Out:
#    fountain_id                                           geometry
# 0            1  POLYGON ((-73.97939 40.76179, -73.97943 40.761...
# 1            2  POLYGON ((-73.97966 40.76141, -73.97970 40.761...
# 2            3  POLYGON ((-73.98771 40.76260, -73.98773 40.762...
# 3            4  POLYGON ((-73.98336 40.77231, -73.98336 40.772...
# 4            5  POLYGON ((-74.00988 40.70265, -74.00989 40.702...

# %%
fountain_gdf= fountain_gdf.to_crs(epsg=32618)

# %%
fountain_gdf['centroid']=fountain_gdf.centroid

# %%
fountain_gdf
# Out:
#      fountain_id                                           geometry  \
# 0              1  POLYGON ((586143.949 4512814.769, 586140.462 4...
# 1              2  POLYGON ((586121.351 4512772.629, 586117.855 4...
# 2              3  POLYGON ((585440.656 4512896.661, 585439.218 4...
# 3              4  POLYGON ((585795.209 4513978.689, 585795.291 4...
# 4              5  POLYGON ((583644.263 4506220.548, 583643.231 4...
# ..           ...                                                ...
# 144          145                     POINT (588443.741 4513376.300)
# 145          146                     POINT (588499.121 4513343.998)
# 146          147                     POINT (587614.001 4517422.605)
# 147          148                     POINT (587035.293 4517263.258)
# 148          149                     POINT (587759.128 4519066.862)
#
#                            centroid
# 0    POINT (586145.543 4512809.753)
# 1    POINT (586122.942 4512767.612)
# 2    POINT (585438.936 4512893.192)
# ...

# %%
fountain_gdf=fountain_gdf.set_geometry('centroid')

# %%
fountain_within_parks=gpd.sjoin(fountain_gdf,unique_parks_gdf,how='inner',predicate='within')

# %%
fountain_counts=fountain_within_parks.groupby('park_id').size().reset_index(name='fountain_count')

# %%
parks_with_amenities=parks_with_amenities.merge(fountain_counts,how='left',on='park_id')

# %%
parks_with_amenities['fountain_count']=parks_with_amenities['fountain_count'].fillna(0)

# %%
parks_with_amenities['fountain_count']=parks_with_amenities['fountain_count'].astype('int64')

# %% [markdown]
# ENDS

# %%
parks_with_amenities
# Out:
#     park_id                  park_name  \
# 0     PK101           Inwood Hill Park
# 1     PK102      Irish Hunger Memorial
# 2     PK103                 Isham Park
# 3     PK104        J. Hood Wright Park
# 4     PK105       Jackie Robinson Park
# ..      ...                        ...
# 186    PK95            Highbridge Park
# 187    PK96               Hillman Park
# 188    PK97       Holcombe Rucker Park
# 189    PK98  Howard Bennett Playground
# 190    PK99          Hudson River Park
#
#                                               geometry  \
# 0    POLYGON ((589997.817 4524833.815, 589997.241 4...
# 1    POLYGON ((583103.656 4507601.684, 583106.215 4...
# 2    POLYGON ((591069.949 4524711.063, 591029.220 4...
# 3    POLYGON ((589297.156 4522150.813, 589144.554 4...
# 4    POLYGON ((589416.276 4520386.839, 589415.408 4...
# ..                                                 ...
# 186  MULTIPOLYGON (((589292.666 4520521.927, 589333...
# ...

# %%
parks_with_amenities.dtypes
# Out:
# park_id                           object
# park_name                         object
# geometry                        geometry
# buffer                          geometry
# cafe_count                         int64
# playground_count                   int64
# toilet_count                       int64
# toilet_handicap_access_count       int64
# restaurant_count                   int64
# shelter_count                      int64
# drinking_water_count               int64
# bar_count                          int64
# bench_count                        int64
# garden_count                       int64
# fountain_count                     int64
# dtype: object

# %%
parks_with_amenities['centroid']=parks_with_amenities.centroid

# %%
parks_with_amenities.head()
# Out:
#   park_id              park_name  \
# 0   PK101       Inwood Hill Park
# 1   PK102  Irish Hunger Memorial
# 2   PK103             Isham Park
# 3   PK104    J. Hood Wright Park
# 4   PK105   Jackie Robinson Park
#
#                                             geometry  \
# 0  POLYGON ((589997.817 4524833.815, 589997.241 4...
# 1  POLYGON ((583103.656 4507601.684, 583106.215 4...
# 2  POLYGON ((591069.949 4524711.063, 591029.220 4...
# 3  POLYGON ((589297.156 4522150.813, 589144.554 4...
# 4  POLYGON ((589416.276 4520386.839, 589415.408 4...
#
#                                               buffer  cafe_count  \
# 0  POLYGON ((589911.751 4524783.056, 589908.223 4...           0
# 1  POLYGON ((583133.288 4507697.599, 583140.538 4...           3
# 2  POLYGON ((590974.905 4524676.718, 590966.700 4...           0
# 3  POLYGON ((589341.577 4522061.360, 589336.870 4...           0
# 4  POLYGON ((589258.233 4519711.282, 589258.092 4...           1
#
# ...

# %%
parks_with_amenities
# Out:
#     park_id                  park_name  \
# 0     PK101           Inwood Hill Park
# 1     PK102      Irish Hunger Memorial
# 2     PK103                 Isham Park
# 3     PK104        J. Hood Wright Park
# 4     PK105       Jackie Robinson Park
# ..      ...                        ...
# 186    PK95            Highbridge Park
# 187    PK96               Hillman Park
# 188    PK97       Holcombe Rucker Park
# 189    PK98  Howard Bennett Playground
# 190    PK99          Hudson River Park
#
#                                               geometry  \
# 0    POLYGON ((589997.817 4524833.815, 589997.241 4...
# 1    POLYGON ((583103.656 4507601.684, 583106.215 4...
# 2    POLYGON ((591069.949 4524711.063, 591029.220 4...
# 3    POLYGON ((589297.156 4522150.813, 589144.554 4...
# 4    POLYGON ((589416.276 4520386.839, 589415.408 4...
# ..                                                 ...
# 186  MULTIPOLYGON (((589292.666 4520521.927, 589333...
# ...

# %%
parks_with_amenities.value_counts().sum()
# Out:
# 191

# %%
parks_with_amenities.columns
# Out:
# Index(['park_id', 'park_name', 'geometry', 'buffer', 'cafe_count',
#        'playground_count', 'toilet_count', 'toilet_handicap_access_count',
#        'restaurant_count', 'shelter_count', 'drinking_water_count',
#        'bar_count', 'bench_count', 'garden_count', 'fountain_count',
#        'centroid'],
#       dtype='object')

# %%
parks_with_amenities_details= parks_with_amenities[['park_id', 'park_name','centroid', 'cafe_count',
       'restaurant_count', 'bar_count', 'playground_count', 'garden_count',
       'toilet_count', 'toilet_handicap_access_count','shelter_count', 'bench_count', 'drinking_water_count',
       'fountain_count']]

# %%
parks_with_amenities_details=parks_with_amenities_details.rename(columns={'centroid':'park_entrance'})

# %%
type(parks_with_amenities_details)
# Out:
# geopandas.geodataframe.GeoDataFrame

# %%
parks_with_amenities_details=parks_with_amenities_details.set_geometry('park_entrance')

# %%
parks_with_amenities_details=parks_with_amenities_details.to_crs(epsg=4326)

# %%
parks_with_amenities_details.dtypes
# Out:
# park_id                           object
# park_name                         object
# park_entrance                   geometry
# cafe_count                         int64
# restaurant_count                   int64
# bar_count                          int64
# playground_count                   int64
# garden_count                       int64
# toilet_count                       int64
# toilet_handicap_access_count       int64
# shelter_count                      int64
# bench_count                        int64
# drinking_water_count               int64
# fountain_count                     int64
# dtype: object

# %%
parks_with_amenities_details.columns
# Out:
# Index(['park_id', 'park_name', 'park_entrance', 'cafe_count',
#        'restaurant_count', 'bar_count', 'playground_count', 'garden_count',
#        'toilet_count', 'toilet_handicap_access_count', 'shelter_count',
#        'bench_count', 'drinking_water_count', 'fountain_count'],
#       dtype='object')

# %%
parks_with_amenities_details
# Out:
#     park_id                  park_name               park_entrance  \
# 0     PK101           Inwood Hill Park  POINT (-73.92558 40.87244)
# 1     PK102      Irish Hunger Memorial  POINT (-74.01654 40.71514)
# 2     PK103                 Isham Park  POINT (-73.91901 40.86966)
# 3     PK104        J. Hood Wright Park  POINT (-73.94125 40.84654)
# 4     PK105       Jackie Robinson Park  POINT (-73.94111 40.82670)
# ..      ...                        ...                         ...
# 186    PK95            Highbridge Park  POINT (-73.93063 40.84636)
# 187    PK96               Hillman Park  POINT (-73.98238 40.71524)
# 188    PK97       Holcombe Rucker Park  POINT (-73.93591 40.82923)
# 189    PK98  Howard Bennett Playground  POINT (-73.93864 40.81364)
# 190    PK99          Hudson River Park  POINT (-74.01336 40.72133)
#
#      cafe_count  restaurant_count  bar_count  playground_count  garden_count  \
# 0             0                 5          1                 3             0
# ...

# %%
#parks_with_amenities_details['park_entrance'] = parks_with_amenities_details['park_entrance'].apply(lambda x: x.wkt if isinstance(x, Point) else x)

# %%
parks_with_amenities_details.dtypes
# Out:
# park_id                           object
# park_name                         object
# park_entrance                   geometry
# cafe_count                         int64
# restaurant_count                   int64
# bar_count                          int64
# playground_count                   int64
# garden_count                       int64
# toilet_count                       int64
# toilet_handicap_access_count       int64
# shelter_count                      int64
# bench_count                        int64
# drinking_water_count               int64
# fountain_count                     int64
# dtype: object

# %%
type(parks_with_amenities_details)
# Out:
# geopandas.geodataframe.GeoDataFrame

# %% [markdown]
# Monument

# %%
monuments_gdf= gpd.read_file('manhattan_monument_geocoded.geojson')

# %%
monuments_gdf.columns
# Out:
# Index(['monument_id', 'monument_name', 'parkprop', 'parkname', 'Location',
#        'geometry'],
#       dtype='object')

# %%
monuments_gdf=monuments_gdf.to_crs(epsg=32618)

# %%
monuments_gdf['centroid']=monuments_gdf.centroid

# %%
monuments_gdf=monuments_gdf.set_geometry('centroid')

# %%
monument_within_parks=gpd.sjoin(monuments_gdf,unique_parks_gdf,how='inner',predicate='within')

# %%
monument_counts=monument_within_parks.groupby('park_id').size().reset_index(name='monument_count')

# %%
parks_with_amenities=parks_with_amenities.merge(monument_counts,how='left',on='park_id')

# %%
parks_with_amenities['monument_count']=parks_with_amenities['monument_count'].fillna(0)

# %%
parks_with_amenities['monument_count']=parks_with_amenities['monument_count'].astype('int64')

# %%
parks_with_amenities['monument_count'].value_counts()
# Out:
# monument_count
# 0      161
# 1       11
# 4        4
# 3        4
# 2        4
# 5        3
# 8        1
# 7        1
# 115      1
# 18       1
# Name: count, dtype: int64

# %%
parks_with_amenities.columns
# Out:
# Index(['park_id', 'park_name', 'geometry', 'buffer', 'cafe_count',
#        'playground_count', 'toilet_count', 'toilet_handicap_access_count',
#        'restaurant_count', 'shelter_count', 'drinking_water_count',
#        'bar_count', 'bench_count', 'garden_count', 'fountain_count',
#        'centroid', 'monument_count'],
#       dtype='object')

# %%
parks_with_amenities_details= parks_with_amenities[['park_id', 'park_name', 'centroid', 'cafe_count',
       'playground_count', 'toilet_count', 'toilet_handicap_access_count',
       'restaurant_count', 'shelter_count', 'drinking_water_count',
       'bar_count', 'bench_count', 'garden_count', 'fountain_count', 'monument_count']]

# %%
parks_with_amenities_details
# Out:
#     park_id                  park_name                        centroid  \
# 0     PK101           Inwood Hill Park  POINT (590534.739 4525152.511)
# 1     PK102      Irish Hunger Memorial  POINT (583065.891 4507601.080)
# 2     PK103                 Isham Park  POINT (591092.806 4524850.475)
# 3     PK104        J. Hood Wright Park  POINT (589249.420 4522261.363)
# 4     PK105       Jackie Robinson Park  POINT (589288.209 4520058.921)
# ..      ...                        ...                             ...
# 186    PK95            Highbridge Park  POINT (590145.346 4522252.515)
# 187    PK96               Hillman Park  POINT (585951.722 4507644.183)
# 188    PK97       Holcombe Rucker Park  POINT (589722.900 4520345.411)
# 189    PK98  Howard Bennett Playground  POINT (589514.040 4518611.427)
# 190    PK99          Hudson River Park  POINT (583326.648 4508291.026)
#
#      cafe_count  playground_count  toilet_count  toilet_handicap_access_count  \
# ...

# %%
type(parks_with_amenities_details)
# Out:
# geopandas.geodataframe.GeoDataFrame

# %%
parks_with_amenities_details=parks_with_amenities_details.set_geometry('centroid')

# %%
parks_with_amenities_details=parks_with_amenities_details.to_crs(epsg=4326)

# %%
parks_with_amenities_details.to_file('parks_with_amenities_details.geojson',driver='GeoJSON')

# %%
parks_with_amenities_details.columns
# Out:
# Index(['park_id', 'park_name', 'centroid', 'cafe_count', 'playground_count',
#        'toilet_count', 'toilet_handicap_access_count', 'restaurant_count',
#        'shelter_count', 'drinking_water_count', 'bar_count', 'bench_count',
#        'garden_count', 'fountain_count', 'monument_count'],
#       dtype='object')

# %%
parks_with_amenities_details.dtypes
# Out:
# park_id                           object
# park_name                         object
# centroid                        geometry
# cafe_count                         int64
# playground_count                   int64
# toilet_count                       int64
# toilet_handicap_access_count       int64
# restaurant_count                   int64
# shelter_count                      int64
# drinking_water_count               int64
# bar_count                          int64
# bench_count                        int64
# garden_count                       int64
# fountain_count                     int64
# monument_count                     int64
# dtype: object

# %% [markdown]
# Converting numbers >1 to 1

# %%
parks_with_amenities_details['cafe_count']=parks_with_amenities_details['cafe_count'].apply(lambda x:1 if x>1 else x)

# %%
parks_with_amenities_details['playground_count']=parks_with_amenities_details['playground_count'].apply(lambda x:1 if x>1 else x)

# %%
parks_with_amenities_details['toilet_count']=parks_with_amenities_details['toilet_count'].apply(lambda x:1 if x>1 else x)

# %%
parks_with_amenities_details['toilet_handicap_access_count']=parks_with_amenities_details['toilet_handicap_access_count'].apply(lambda x:1 if x>1 else x)

# %%
parks_with_amenities_details['restaurant_count']=parks_with_amenities_details['restaurant_count'].apply(lambda x:1 if x>1 else x)

# %%
parks_with_amenities_details['shelter_count']=parks_with_amenities_details['shelter_count'].apply(lambda x:1 if x>1 else x)

# %%
parks_with_amenities_details['drinking_water_count']=parks_with_amenities_details['drinking_water_count'].apply(lambda x:1 if x>1 else x)

# %%
parks_with_amenities_details['bar_count']=parks_with_amenities_details['bar_count'].apply(lambda x:1 if x>1 else x)

# %%
parks_with_amenities_details['bench_count']=parks_with_amenities_details['bench_count'].apply(lambda x:1 if x>1 else x)

# %%
parks_with_amenities_details['garden_count']=parks_with_amenities_details['garden_count'].apply(lambda x:1 if x>1 else x)

# %%
parks_with_amenities_details['fountain_count']=parks_with_amenities_details['fountain_count'].apply(lambda x:1 if x>1 else x)

# %%
parks_with_amenities_details['monument_count']=parks_with_amenities_details['monument_count'].apply(lambda x:1 if x>1 else x)

# %%
parks_with_amenities_details
# Out:
#     park_id                  park_name                    centroid  \
# 0     PK101           Inwood Hill Park  POINT (-73.92558 40.87244)
# 1     PK102      Irish Hunger Memorial  POINT (-74.01654 40.71514)
# 2     PK103                 Isham Park  POINT (-73.91901 40.86966)
# 3     PK104        J. Hood Wright Park  POINT (-73.94125 40.84654)
# 4     PK105       Jackie Robinson Park  POINT (-73.94111 40.82670)
# ..      ...                        ...                         ...
# 186    PK95            Highbridge Park  POINT (-73.93063 40.84636)
# 187    PK96               Hillman Park  POINT (-73.98238 40.71524)
# 188    PK97       Holcombe Rucker Park  POINT (-73.93591 40.82923)
# 189    PK98  Howard Bennett Playground  POINT (-73.93864 40.81364)
# 190    PK99          Hudson River Park  POINT (-74.01336 40.72133)
#
#      cafe_count  playground_count  toilet_count  toilet_handicap_access_count  \
# 0             0                 1             1                             0
# ...

# %%
#parks_with_amenities_details.to_file('parks_with_amenities_details.geojson',driver='GeoJSON')

# %% [markdown]
# Convert geometry to lat lng

# %%
parks_with_amenities_details.head()
# Out:
#   park_id              park_name                    centroid  cafe_count  \
# 0   PK101       Inwood Hill Park  POINT (-73.92558 40.87244)           0
# 1   PK102  Irish Hunger Memorial  POINT (-74.01654 40.71514)           1
# 2   PK103             Isham Park  POINT (-73.91901 40.86966)           0
# 3   PK104    J. Hood Wright Park  POINT (-73.94125 40.84654)           0
# 4   PK105   Jackie Robinson Park  POINT (-73.94111 40.82670)           1
#
#    playground_count  toilet_count  toilet_handicap_access_count  \
# 0                 1             1                             0
# 1                 0             0                             0
# 2                 0             0                             0
# 3                 1             0                             0
# 4                 1             1                             0
#
#    restaurant_count  shelter_count  drinking_water_count  bar_count  \
# 0                 1              0                     1          1
# ...

# %%
parks_with_amenities_details['lon'] = parks_with_amenities_details.geometry.x
parks_with_amenities_details['lat'] = parks_with_amenities_details.geometry.y

# %%
entrance=dict(zip(parks_with_amenities_details['lat'], parks_with_amenities_details['lon']))

# %%
parks_with_amenities_details['park_entrance']= [{'lat':lat, 'lon':lon} for lat, lon in zip(parks_with_amenities_details['lat'], parks_with_amenities_details['lon'])]

# %%
parks_with_amenities_details
# Out:
#     park_id                  park_name                    centroid  \
# 0     PK101           Inwood Hill Park  POINT (-73.92558 40.87244)
# 1     PK102      Irish Hunger Memorial  POINT (-74.01654 40.71514)
# 2     PK103                 Isham Park  POINT (-73.91901 40.86966)
# 3     PK104        J. Hood Wright Park  POINT (-73.94125 40.84654)
# 4     PK105       Jackie Robinson Park  POINT (-73.94111 40.82670)
# ..      ...                        ...                         ...
# 186    PK95            Highbridge Park  POINT (-73.93063 40.84636)
# 187    PK96               Hillman Park  POINT (-73.98238 40.71524)
# 188    PK97       Holcombe Rucker Park  POINT (-73.93591 40.82923)
# 189    PK98  Howard Bennett Playground  POINT (-73.93864 40.81364)
# 190    PK99          Hudson River Park  POINT (-74.01336 40.72133)
#
#      cafe_count  playground_count  toilet_count  toilet_handicap_access_count  \
# 0             0                 1             1                             0
# ...

# %%
import json

# %%
parks_with_amenities_details.columns
# Out:
# Index(['park_id', 'park_name', 'centroid', 'cafe_count', 'playground_count',
#        'toilet_count', 'toilet_handicap_access_count', 'restaurant_count',
#        'shelter_count', 'drinking_water_count', 'bar_count', 'bench_count',
#        'garden_count', 'fountain_count', 'monument_count', 'lon', 'lat',
#        'park_entrance'],
#       dtype='object')

# %%
parks_with_amenities_details['park_entrance']= parks_with_amenities_details['park_entrance'].apply(lambda row: json.dumps(row))

# %%
parks_with_amenities_details.dtypes
# Out:
# park_id                           object
# park_name                         object
# centroid                        geometry
# cafe_count                         int64
# playground_count                   int64
# toilet_count                       int64
# toilet_handicap_access_count       int64
# restaurant_count                   int64
# shelter_count                      int64
# drinking_water_count               int64
# bar_count                          int64
# bench_count                        int64
# garden_count                       int64
# fountain_count                     int64
# monument_count                     int64
# lon                              float64
# lat                              float64
# park_entrance                     object
# dtype: object

# %%
df1= parks_with_amenities_details.drop(['lon','lat','centroid'],axis=1)

# %%
df1.columns
# Out:
# Index(['park_id', 'park_name', 'cafe_count', 'playground_count',
#        'toilet_count', 'toilet_handicap_access_count', 'restaurant_count',
#        'shelter_count', 'drinking_water_count', 'bar_count', 'bench_count',
#        'garden_count', 'fountain_count', 'monument_count', 'park_entrance'],
#       dtype='object')

# %%
df1=df1[['park_id', 'park_name', 'park_entrance', 'cafe_count', 'playground_count',
       'toilet_count', 'toilet_handicap_access_count', 'restaurant_count',
       'shelter_count', 'drinking_water_count', 'bar_count', 'bench_count',
       'garden_count', 'fountain_count', 'monument_count']]

# %%
df1['park_entrance']=df1['park_entrance'].values.tolist()

# %%
df1
# Out:
#     park_id                  park_name  \
# 0     PK101           Inwood Hill Park
# 1     PK102      Irish Hunger Memorial
# 2     PK103                 Isham Park
# 3     PK104        J. Hood Wright Park
# 4     PK105       Jackie Robinson Park
# ..      ...                        ...
# 186    PK95            Highbridge Park
# 187    PK96               Hillman Park
# 188    PK97       Holcombe Rucker Park
# 189    PK98  Howard Bennett Playground
# 190    PK99          Hudson River Park
#
#                                          park_entrance  cafe_count  \
# 0    {"lat": 40.87244138917063, "lon": -73.92558454...           0
# 1    {"lat": 40.715143165788184, "lon": -74.0165433...           1
# 2    {"lat": 40.869659121511106, "lon": -73.9190070...           0
# 3    {"lat": 40.846542118990286, "lon": -73.9412502...           0
# 4    {"lat": 40.82670060262777, "lon": -73.94110589...           1
# ..                                                 ...         ...
# ...

# %%
df1.to_csv('db_parks_with_amenities_test.csv',index=False)

# %%
type(parks_with_amenities_details)
# Out:
# geopandas.geodataframe.GeoDataFrame
