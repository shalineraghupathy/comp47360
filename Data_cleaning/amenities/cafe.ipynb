# %%
import pandas as pd
import geopandas as gpd
import matplotlib.pyplot as plt
from shapely.geometry import Point

# Load data
cafe_gdf = gpd.read_file("cafe.geojson")

# %%
pd.set_option('display.max_columns', None)
#display all columns not truncated

# %%
cafe_gdf
# Out:
#                     id               @id access addr:city addr:country  \
# 0        way/247842926     way/247842926   None      None         None
# 1        way/247862492     way/247862492   None  New York         None
# 2        way/248773591     way/248773591   None      None         None
# 3        way/249665284     way/249665284   None      None         None
# 4        way/250072763     way/250072763   None      None         None
# ...                ...               ...    ...       ...          ...
# 1115  node/11963623561  node/11963623561   None  New York         None
# 1116  node/11963636514  node/11963636514   None  New York         None
# 1117  node/11968161061  node/11968161061   None      None         None
# 1118  node/11969362706  node/11969362706   None      None         None
# 1119  node/11980017793  node/11980017793   None  New York         None
#
#      addr:county addr:floor addr:housename addr:housenumber addr:postcode  \
# ...

# %%
cafe_gdf.columns
# Out:
# Index(['id', '@id', 'access', 'addr:city', 'addr:country', 'addr:county',
#        'addr:floor', 'addr:housename', 'addr:housenumber', 'addr:postcode',
#        ...
#        'twitter', 'walkup_window', 'website', 'website:menu', 'wheelchair',
#        'wheelchair:description', 'wifi', 'wikidata', 'wikipedia', 'geometry'],
#       dtype='object', length=211)

# %%
#checking for duplicated rows
duplicate_rows = cafe_gdf[cafe_gdf.duplicated()]

#display duplicate rows
print("Duplicate Rows:")
print(duplicate_rows)

#Results: there are no duplicated rows
# Out:
# Duplicate Rows:
# Empty GeoDataFrame
# ...

# %%
cafe_gdf.isnull().sum()
# Out:
# id                           0
# @id                          0
# access                    1116
# addr:city                  666
# addr:country              1069
#                           ...
# wheelchair:description    1119
# wifi                      1119
# wikidata                  1114
# wikipedia                 1118
# geometry                     0
# Length: 211, dtype: int64

# %%
import folium 
import matplotlib.pyplot as plt
import mapclassify

# %%
cafe_gdf_name=cafe_gdf[['name','cuisine','geometry']]
cafe_gdf_name
# Out:
#                                      name                        cuisine  \
# 0                       Le Pain Quotidien                    coffee_shop
# 1                             Bagel Belly                 bagel;sandwich
# 2                       Le Pain Quotidien                    coffee_shop
# 3                          Bluestone Lane                    coffee_shop
# 4                       La Contenta Oeste                           None
# ...                                   ...                            ...
# 1115                       Forever Coffee                           None
# 1116  Barnes & Noble CUIMC Bookstore Cafe                           None
# 1117                 Vanilla Gorilla Cafe  coffee_shop;sandwich;pastrino
# 1118                      Jooy Tea Shoppe                     bubble_tea
# 1119                  Omega Bakery & Cafe                           None
#
#                                                geometry
# ...

# %%
cafe_gdf["area"] = cafe_gdf.area
cafe_gdf["area"]
# Out:
# C:\Users\Justh\AppData\Local\Temp\ipykernel_17256\2551690.py:1: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   cafe_gdf["area"] = cafe_gdf.area
# 0       7.314968e-08
# 1       2.593864e-08
# 2       7.022890e-09
# 3       1.439770e-08
# 4       2.367075e-08
#             ...
# 1115    0.000000e+00
# 1116    0.000000e+00
# 1117    0.000000e+00
# 1118    0.000000e+00
# 1119    0.000000e+00
# Name: area, Length: 1120, dtype: float64

# %%
print(cafe_gdf.geometry.name)
# Out:
# geometry

# %%
cafe_gdf_name.explore("name", legend=True)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
# ...

# %% [markdown]
# ### Notes: buffering techinque to map nearby cafes?
