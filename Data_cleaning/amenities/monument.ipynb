# %%
import geopandas as gpd 
from shapely.wkt import loads
import pandas as pd

# %%
pd.set_option('display.max_columns', None)
#display all columns not truncated

# %%
monument=pd.read_csv('NYC_Parks_Monuments_20240707.csv')

# %%
monument= monument[monument['borough']=='Manhattan']

# %%
monument.shape
# Out:
# (1423, 34)

# %%
monument.head()
# Out:
#                  name            fileorder  number parkprop    borough  \
# 2           Cigarette            Cigarette    1937        N  Manhattan
# 3          Philosophy                  NaN    1181        O  Manhattan
# 4  Giuseppe Garibaldi  Garibaldi, Giuseppe     571        Y  Manhattan
# 6  Alexander Hamilton                  NaN     663        N  Manhattan
# 7            Commerce             Commerce     306        N  Manhattan
#
#                  parkname parknumber  commboard  council  \
# 2                     NaN        NaN        5.0      3.0
# 3             Bryant Park       M008        5.0      3.0
# 4  Washington Square Park       M098        2.0      1.0
# 6                     NaN        NaN        1.0      1.0
# 7                     NaN        NaN        1.0      1.0
#
#                                             Location extant     dedicated  \
# 2      The Museum of Modern Art, 11 West 53rd Street      Y     June 1980
# ...

# %%
monument.columns
# Out:
# Index(['name', 'fileorder', 'number', 'parkprop', 'borough', 'parkname',
#        'parknumber', 'commboard', 'council', 'Location', 'extant', 'dedicated',
#        'cast', 'descrip', 'dimen', 'sponsor', 'materials', 'foundry',
#        'fabricator', 'sculptor', 'architect', 'donor', 'maintain',
#        'contractor', 'Name2', 'Name3', 'MaintainedByParks', 'Installation',
#        'Rededication', 'Cost', 'Categories', 'inscribed', 'X', 'Y'],
#       dtype='object')

# %%
monument.duplicated().sum()
# Out:
# 484

# %%
monument=monument.drop_duplicates()

# %%
monument.dtypes
# Out:
# name                  object
# fileorder             object
# number                 int64
# parkprop              object
# borough               object
# parkname              object
# parknumber            object
# commboard            float64
# council              float64
# Location              object
# extant                object
# dedicated             object
# cast                  object
# descrip               object
# dimen                 object
# sponsor               object
# materials             object
# foundry               object
# fabricator            object
# sculptor              object
# architect             object
# donor                 object
# maintain              object
# contractor            object
# Name2                 object
# Name3                 object
# MaintainedByParks     object
# Installation          object
# Rededication          object
# Cost                  object
# Categories            object
# inscribed            float64
# ...

# %%
monument['extant'].value_counts()
# Out:
# extant
# Y     762
# M      83
# N      64
# S      19
# L       9
# NM      1
# Name: count, dtype: int64

# %%
monument.columns
# Out:
# Index(['name', 'fileorder', 'number', 'parkprop', 'borough', 'parkname',
#        'parknumber', 'commboard', 'council', 'Location', 'extant', 'dedicated',
#        'cast', 'descrip', 'dimen', 'sponsor', 'materials', 'foundry',
#        'fabricator', 'sculptor', 'architect', 'donor', 'maintain',
#        'contractor', 'Name2', 'Name3', 'MaintainedByParks', 'Installation',
#        'Rededication', 'Cost', 'Categories', 'inscribed', 'X', 'Y'],
#       dtype='object')

# %%
monument_details= monument[['name', 'parkprop', 'parkname',
       'Location', 'extant', 'X', 'Y']]

# %%
monument_details.isnull().sum()
# Out:
# name          0
# parkprop      2
# parkname    381
# Location     76
# extant        1
# X           461
# Y           461
# dtype: int64

# %%
monument_details=monument_details.drop(columns=['X','Y'])

# %%
monument_details=monument_details[monument_details['extant']=='Y']

# %%
monument_details
# Out:
#                                         name parkprop                parkname  \
# 2                                  Cigarette        N                     NaN
# 3                                 Philosophy        O             Bryant Park
# 4                         Giuseppe Garibaldi        Y  Washington Square Park
# 6                         Alexander Hamilton        N                     NaN
# 7                                   Commerce        N                     NaN
# ...                                      ...      ...                     ...
# 1906  Jewish-American Tercentenary Flagstaff        Y       Peter Minuit Park
# 1907               Cheetah, Leopard and Puma        O            Central Park
# 2628        Jeffrey's Hook Lighthouse Plaque        Y    Fort Washington Park
# 2806                    Coast Guard Memorial        Y            Battery Park
# 2812                          Discus Thrower        Y    Randalls Island Park
#
# ...

# %%
import requests

def geocode(address,api_key):
    geocode_url= 'https://maps.googleapis.com/maps/api/geocode/json'

    params= {'address':address, 'key': api_key}

    response=requests.get(geocode_url,params=params)
    result=response.json()

    if result['status'] =='OK':
        outcome= result['results'][0]['geometry']['location']
        lat=outcome['lat']
        lng=outcome['lng']
        return lat,lng
    else:
        raise Exception(f"Error in geocoding request: {result['status']}")

# %%
api_key= 'AIzaSyAvr9o38Xk159Uh4BTvDkKrKLvO7t9VvxU'

# %%
for index,row in monument_details.iterrows():
    try:
        address=row['Location']
        lat,lng= geocode(address,api_key)
        monument_details.at[index, 'Latitude'] =lat
        monument_details.at[index, 'Longitude'] =lng
        print(f'Success geocoding location {address}')
    except Exception as e:
        print(f'Error geocoding location {address} :{e}')
        try:
            address = row['parkname']
            lat, lng = geocode(address, api_key)
            monument_details.at[index, 'Latitude'] = lat
            monument_details.at[index, 'Longitude'] = lng
            print(f'Success geocoding name {address}')
        except Exception as e:
            print(f'Error geocoding name {address}: {e}')
            monument_details.at[index, 'Latitude'] = None
            monument_details.at[index, 'Longitude'] = None
# Out:
# C:\Users\Justh\AppData\Local\Temp\ipykernel_1388\1508216764.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   monument_details.at[index, 'Latitude'] =lat
# C:\Users\Justh\AppData\Local\Temp\ipykernel_1388\1508216764.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   monument_details.at[index, 'Longitude'] =lng
# Success geocoding location The Museum of Modern Art, 11 West 53rd Street
# Success geocoding location New York Public Library; 42nd St. and 5th Avenue
# ...

# %%
monument_details = gpd.GeoDataFrame(monument_details, geometry=gpd.points_from_xy(monument_details.Longitude, monument_details.Latitude))

# %%
monument_details
# Out:
#                                         name parkprop                parkname  \
# 2                                  Cigarette        N                     NaN
# 3                                 Philosophy        O             Bryant Park
# 4                         Giuseppe Garibaldi        Y  Washington Square Park
# 6                         Alexander Hamilton        N                     NaN
# 7                                   Commerce        N                     NaN
# ...                                      ...      ...                     ...
# 1906  Jewish-American Tercentenary Flagstaff        Y       Peter Minuit Park
# 1907               Cheetah, Leopard and Puma        O            Central Park
# 2628        Jeffrey's Hook Lighthouse Plaque        Y    Fort Washington Park
# 2806                    Coast Guard Memorial        Y            Battery Park
# 2812                          Discus Thrower        Y    Randalls Island Park
#
# ...

# %%
monument_details=monument_details.fillna('unknown')

# %%
monument_details.duplicated().value_counts()
# Out:
# False    741
# True      21
# Name: count, dtype: int64

# %%
monument_details.head()
# Out:
#                  name parkprop                parkname  \
# 2           Cigarette        N                 unknown
# 3          Philosophy        O             Bryant Park
# 4  Giuseppe Garibaldi        Y  Washington Square Park
# 6  Alexander Hamilton        N                 unknown
# 7            Commerce        N                 unknown
#
#                                             Location extant   Latitude  \
# 2      The Museum of Modern Art, 11 West 53rd Street      Y  40.761433
# 3   New York Public Library; 42nd St. and 5th Avenue      Y  40.753182
# 4                                            unknown      Y  40.730884
# 6  COUNTY COURT HOUSE, ROOM 315; chambers and cen...      Y    unknown
# 7  Surrogate's Court/Hall of Records, 31 Chambers...      Y  40.713436
#
#    Longitude                    geometry
# 2 -73.977622  POINT (-73.97762 40.76143)
# 3 -73.982253  POINT (-73.98225 40.75318)
# 4 -73.997332  POINT (-73.99733 40.73088)
# ...

# %%
type(monument_details)
# Out:
# geopandas.geodataframe.GeoDataFrame

# %%
#checking for duplicated rows
duplicate_rows = monument_details[monument_details.duplicated()]

#display duplicate rows
print("Duplicate Rows:")
print(duplicate_rows)
# Out:
# Duplicate Rows:
#                                name parkprop              parkname  \
# 375         Urns - central park (4)        Y          Central Park
# 443                          Eagles        Y          Central Park
# 530         Urns - central park (4)        Y          Central Park
# 531               Wien Walk Plaques        Y          Central Park
# 551            Christopher Columbus        Y          Central Park
# 557                          Eagles        Y          Central Park
# 573                          Eagles        Y          Central Park
# 578                          Eagles        Y          Central Park
# 589         Urns - central park (4)        Y          Central Park
# 669                          Eagles        Y          Central Park
# 683                          Eagles        Y          Central Park
# 708               Wien Walk Plaques        Y          Central Park
# 721                             Zoo        Y          Central Park
# ...

# %%
monument_details=monument_details.drop_duplicates()

# %%
monument_details=monument_details.reset_index()

# %%
monument_details=monument_details.drop(columns='index')

# %%
monument_details['monument_id']=monument_details.index +1

# %%
monument_details=monument_details.drop(columns=['Latitude','Longitude'])

# %%
monument_details=monument_details.drop(columns=['extant'])

# %%
monument_details.columns
# Out:
# Index(['name', 'parkprop', 'parkname', 'Location', 'geometry', 'monument_id'], dtype='object')

# %%
monument_details=monument_details.rename(columns={'name':'monument_name'})

# %%
monument_details=monument_details[['monument_id','monument_name', 'parkprop', 'parkname', 'Location', 'geometry', ]]

# %%
monument_details.to_csv('manhattan_monument_geocoded.csv',index=False)

# %%
monument_details.to_file('manhattan_monument_geocoded.geojson',driver='GeoJSON')

# %%
monument_details.isnull().sum()
# Out:
# monument_id      0
# monument_name    0
# parkprop         0
# parkname         0
# Location         0
# geometry         0
# dtype: int64
