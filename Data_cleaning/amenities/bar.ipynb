# %%
import pandas as pd
import geopandas as gpd
import matplotlib.pyplot as plt
from shapely.geometry import Point

# %%
bar_gdf=gpd.read_file('bar.geojson')

# %%
pd.set_option('display.max_columns', None)
#display all columns not truncated

# %%
bar_gdf.head()
# Out:
#               id            @id access addr:city addr:country addr:floor  \
# 0  way/247842935  way/247842935   None      None         None       None
# 1  way/248142617  way/248142617   None      None         None       None
# 2  way/248234588  way/248234588   None      None         None       None
# 3  way/249657797  way/249657797   None  New York         None       None
# 4  way/249665003  way/249665003   None  New York         None       None
#
#   addr:housename addr:housenumber addr:level addr:postcode addr:state  \
# 0           None              686       None         10012       None
# 1           None              102       None         10009       None
# 2           None               80       None         10012       None
# 3           None              188       None         10009         NY
# 4           None              222       None          None         NY
#
#            addr:street addr:suite addr:unit air_conditioning  \
# ...

# %%
bar_gdf.isnull().sum()
# Out:
# id                0
# @id               0
# access          576
# addr:city       401
# addr:country    563
#                ...
# wheelchair      488
# whisky          577
# wikidata        564
# wikipedia       573
# geometry          0
# Length: 149, dtype: int64

# %%
bar_gdf
# Out:
#                    id               @id access addr:city addr:country  \
# 0       way/247842935     way/247842935   None      None         None
# 1       way/248142617     way/248142617   None      None         None
# 2       way/248234588     way/248234588   None      None         None
# 3       way/249657797     way/249657797   None  New York         None
# 4       way/249665003     way/249665003   None  New York         None
# ..                ...               ...    ...       ...          ...
# 573  node/11943293175  node/11943293175   None  New York         None
# 574  node/11959321244  node/11959321244   None      None         None
# 575  node/11959453564  node/11959453564   None      None         None
# 576  node/11969588269  node/11969588269   None      None         None
# 577  node/11992808706  node/11992808706   None      None         None
#
#     addr:floor addr:housename addr:housenumber addr:level addr:postcode  \
# ...

# %%
bar_gdf_details=bar_gdf[['id','name','geometry']]
bar_gdf_details
# Out:
#                    id                       name  \
# 0       way/247842935  Great Jones Distilling Co
# 1       way/248142617                Proletariat
# 2       way/248234588                 Amity Hall
# 3       way/249657797                    Hi-Note
# 4       way/249665003               Houston Hall
# ..                ...                        ...
# 573  node/11943293175                     Dahlia
# 574  node/11959321244                Proletariat
# 575  node/11959453564                      Talea
# 576  node/11969588269          The Three Monkeys
# 577  node/11992808706                  Blue Ruin
#
#                                               geometry
# 0    POLYGON ((-73.99447 40.72796, -73.99407 40.727...
# 1    POLYGON ((-73.98466 40.72705, -73.98455 40.727...
# 2    POLYGON ((-73.99895 40.72953, -73.99881 40.729...
# 3    POLYGON ((-73.97926 40.72792, -73.97926 40.727...
# 4    POLYGON ((-74.00461 40.72880, -74.00464 40.728...
# ...

# %%
bar_gdf_details.isnull().sum()
# Out:
# id          0
# name        3
# geometry    0
# dtype: int64

# %%
bar_gdf_details=bar_gdf_details.rename(columns={'id':'bar_id','name':'bar_name'})

# %%
bar_gdf_details.crs
# Out:
# <Geographic 2D CRS: EPSG:4326>
# Name: WGS 84
# Axis Info [ellipsoidal]:
# - Lat[north]: Geodetic latitude (degree)
# - Lon[east]: Geodetic longitude (degree)
# Area of Use:
# - undefined
# Datum: World Geodetic System 1984
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %%
bar_gdf_details=bar_gdf_details.to_crs(epsg=32618)

# %%
bar_gdf_details['centroid']=bar_gdf_details.centroid

# %%
bar_gdf_details=bar_gdf_details.set_geometry('centroid')

# %%
bar_gdf_details=bar_gdf_details.to_crs(epsg=4326)

# %%
bar_gdf_details['bar_name']=bar_gdf_details['bar_name'].fillna('unknown')

# %%
bar_gdf_details.isnull().sum()
# Out:
# bar_id      0
# bar_name    0
# geometry    0
# centroid    0
# dtype: int64

# %%
import requests

def reverse_geocode(lat,lng,api_key):
    geocode_url= 'https://maps.googleapis.com/maps/api/geocode/json'

    params= {'latlng':f'{lat},{lng}', 'key': api_key}

    response=requests.get(geocode_url,params=params)
    outcome=response.json()

    if outcome['status'] =='OK':
        final_outcome=outcome['results'][0]['formatted_address']
        return final_outcome
    else:
        raise Exception(f"Error in geocoding request: {outcome['status']}")

# %%
api_key= 'AIzaSyAvr9o38Xk159Uh4BTvDkKrKLvO7t9VvxU'

# %%
for index,row in bar_gdf_details.iterrows():
    if row['bar_name']=='unknown':
        try:
            lat=row['centroid'].y
            lng=row['centroid'].x
            name= reverse_geocode(lat,lng,api_key)
            bar_gdf_details.at[index, 'bar_name'] =name
            print(f'Success geocoding location {row['bar_name']}')
        except Exception as e:
            print(f'Error geocoding address at {row['bar_name']} :{e}')
# Out:
# Success geocoding location unknown
# Success geocoding location unknown
# Success geocoding location unknown

# %%
bar_gdf_details=bar_gdf_details.drop('centroid',axis=1)

# %%
bar_gdf_details=bar_gdf_details.set_geometry('geometry')

# %%
bar_gdf_details=bar_gdf_details.to_crs(epsg=4326)

# %%
bar_gdf_details.to_file('bar_cleaned.geojson',driver='GeoJSON')
