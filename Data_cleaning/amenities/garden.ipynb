# %%
import pandas as pd
import geopandas as gpd
import matplotlib.pyplot as plt
from shapely.geometry import Point

# Load data
garden_gdf = gpd.read_file("garden.geojson")

# %%
pd.set_option('display.max_columns', None)
#display all columns not truncated

# %%
garden_gdf
# Out:
#                      id                @id access addr:city addr:housename  \
# 0      relation/8288693   relation/8288693   None      None           None
# 1      relation/9506392   relation/9506392   None      None           None
# 2      relation/9506393   relation/9506393   None      None           None
# 3     relation/10925250  relation/10925250     no      None           None
# 4     relation/12714129  relation/12714129   None      None           None
# ...                 ...                ...    ...       ...            ...
# 4318   node/11885218980   node/11885218980    yes      None           None
# 4319   node/11885218981   node/11885218981    yes      None           None
# 4320   node/11885218986   node/11885218986    yes      None           None
# 4321   node/11906951072   node/11906951072   None      None           None
# 4322   node/11906951073   node/11906951073   None      None           None
#
#      addr:housenumber addr:postcode addr:state addr:street alt_name  area  \
# 0                None          None       None        None     None  None
# 1                None          None       None        None     None  None
# 2                None          None       None        None     None  None
# 3                None          None       None        None     None  None
# 4                None          None       None        None     None  None
# ...               ...           ...        ...         ...      ...   ...
# 4318             None          None       None        None     None  None
# 4319             None          None       None        None     None  None
# 4320             None          None       None        None     None  None
# 4321             None          None       None        None     None  None
# 4322             None          None       None        None     None  None
#
#      barrier building check_date contact:facebook contact:instagram  \
# 0       None     None       None             None              None
# 1       None     None       None             None              None
# 2       None     None       None             None              None
# 3       None     None       None             None              None
# 4       None     None       None             None              None
# ...      ...      ...        ...              ...               ...
# 4318    None     None       None             None              None
# 4319    None     None       None             None              None
# 4320    None     None       None             None              None
# 4321    None     None       None             None              None
# 4322    None     None       None             None              None
#
#                     description   ele email   fee fence fixme  \
# 0                          None  None  None  None  None  None
# 1                          None  None  None  None  None  None
# 2                          None  None  None  None  None  None
# 3                          None  None  None  None  None  None
# 4                          None  None  None  None  None  None
# ...                         ...   ...   ...   ...   ...   ...
# 4318                       None  None  None    no  None  None
# 4319                       None  None  None    no  None  None
# 4320  Not planted. Packed soil.  None  None    no  None  None
# 4321                       None  None  None  None  None  None
# 4322                       None  None  None  None  None  None
#
#                                                  flickr  garden:type  \
# 0                                                  None         None
# 1                                                  None         None
# 2                                                  None         None
# 3                                                  None         None
# 4                                                  None         None
# ...                                                 ...          ...
# 4318                                               None  street_side
# 4319  https://www.flickr.com/photos/40227437@N00/537...  street_side
# 4320                                               None  street_side
# 4321                                               None         None
# 4322                                               None         None
#
#      gnis:feature_id height last_checked layer leisure level   lit loc_name  \
# 0               None   None         None  None  garden  None  None     None
# 1               None   None         None     1  garden  None  None     None
# 2               None   None         None  None  garden  None  None     None
# 3               None   None         None  None  garden  None  None     None
# 4               None   None         None  None  garden  None  None     None
# ...              ...    ...          ...   ...     ...   ...   ...      ...
# 4318            None   None         None  None  garden  None  None     None
# 4319            None   None         None  None  garden  None  None     None
# 4320            None   None         None  None  garden  None  None     None
# 4321            None   None         None  None  garden  None  None     None
# 4322            None   None         None  None  garden  None  None     None
#
#      location material  name name:etymology name:etymology:wikidata name:hr  \
# 0        None     None  None           None                    None    None
# 1        None     None  None           None                    None    None
# 2        None     None  None           None                    None    None
# 3        None     None  None           None                    None    None
# 4        None     None  None           None                    None    None
# ...       ...      ...   ...            ...                     ...     ...
# 4318     None     None  None           None                    None    None
# 4319     None     None  None           None                    None    None
# 4320     None     None  None           None                    None    None
# 4321     None     None  None           None                    None    None
# 4322     None     None  None           None                    None    None
#
#      natural  note official_name old_name opening_hours opening_hours:signed  \
# 0       None  None          None     None          None                 None
# 1       None  None          None     None          None                 None
# 2       None  None          None     None          None                 None
# 3       None  None          None     None          None                 None
# 4       None  None          None     None          None                 None
# ...      ...   ...           ...      ...           ...                  ...
# 4318    None  None          None     None          None                 None
# 4319    None  None          None     None          None                 None
# 4320    None  None          None     None          None                 None
# 4321    None  None          None     None          None                 None
# 4322    None  None          None     None          None                 None
#
#      operator operator:type phone recycling:compost smoking source start_date  \
# 0        None          None  None              None    None   None       None
# 1        None          None  None              None    None   None       None
# 2        None          None  None              None    None   None       None
# 3        None          None  None              None    None   None       None
# 4        None          None  None              None    None   None       None
# ...       ...           ...   ...               ...     ...    ...        ...
# 4318     None          None  None              None    None   None       None
# 4319     None          None  None              None    None   None       None
# 4320     None          None  None              None    None   None       None
# 4321     None          None  None              None    None   None       None
# 4322     None          None  None              None    None   None       None
#
#      surface          type website wheelchair wikidata wikipedia  \
# 0       None  multipolygon    None       None     None      None
# 1       None  multipolygon    None       None     None      None
# 2       None  multipolygon    None       None     None      None
# 3       None  multipolygon    None       None     None      None
# 4       None  multipolygon    None       None     None      None
# ...      ...           ...     ...        ...      ...       ...
# 4318    None          None    None       None     None      None
# 4319    None          None    None       None     None      None
# 4320    None          None    None       None     None      None
# 4321    None          None    None       None     None      None
# 4322    None          None    None       None     None      None
#
#                                                geometry
# 0     MULTIPOLYGON (((-73.93347 40.78810, -73.93360 ...
# 1     POLYGON ((-74.01319 40.70985, -74.01306 40.709...
# 2     POLYGON ((-74.01334 40.70987, -74.01331 40.709...
# 3     MULTIPOLYGON (((-73.99014 40.77391, -73.99014 ...
# 4     POLYGON ((-73.99953 40.74948, -73.99954 40.749...
# ...                                                 ...
# 4318                         POINT (-73.97173 40.79990)
# 4319                         POINT (-73.97180 40.79980)
# 4320                         POINT (-73.97152 40.80016)
# 4321                         POINT (-73.96962 40.79868)
# 4322                         POINT (-73.96973 40.79873)
#
# [4323 rows x 58 columns]

# %%
#checking for duplicated rows
duplicate_rows = garden_gdf[garden_gdf.duplicated()]

#display duplicate rows
print("Duplicate Rows:")
print(duplicate_rows)

#Results: there are no duplicated rows
# Out:
# Duplicate Rows:
# Empty GeoDataFrame
# Columns: [id, @id, access, addr:city, addr:housename, addr:housenumber, addr:postcode, addr:state, addr:street, alt_name, area, barrier, building, check_date, contact:facebook, contact:instagram, description, ele, email, fee, fence, fixme, flickr, garden:type, gnis:feature_id, height, last_checked, layer, leisure, level, lit, loc_name, location, material, name, name:etymology, name:etymology:wikidata, name:hr, natural, note, official_name, old_name, opening_hours, opening_hours:signed, operator, operator:type, phone, recycling:compost, smoking, source, start_date, surface, type, website, wheelchair, wikidata, wikipedia, geometry]
# Index: []

# %%
garden_gdf.columns
# Out:
# Index(['id', '@id', 'access', 'addr:city', 'addr:housename',
#        'addr:housenumber', 'addr:postcode', 'addr:state', 'addr:street',
#        'alt_name', 'area', 'barrier', 'building', 'check_date',
#        'contact:facebook', 'contact:instagram', 'description', 'ele', 'email',
#        'fee', 'fence', 'fixme', 'flickr', 'garden:type', 'gnis:feature_id',
#        'height', 'last_checked', 'layer', 'leisure', 'level', 'lit',
#        'loc_name', 'location', 'material', 'name', 'name:etymology',
#        'name:etymology:wikidata', 'name:hr', 'natural', 'note',
#        'official_name', 'old_name', 'opening_hours', 'opening_hours:signed',
#        'operator', 'operator:type', 'phone', 'recycling:compost', 'smoking',
#        'source', 'start_date', 'surface', 'type', 'website', 'wheelchair',
#        'wikidata', 'wikipedia', 'geometry'],
#       dtype='object')

# %%
garden_gdf.isnull().sum()
# Out:
# id                            0
# @id                           0
# access                     4253
# addr:city                  4288
# addr:housename             4322
# addr:housenumber           4285
# addr:postcode              4286
# addr:state                 4289
# addr:street                4283
# alt_name                   4316
# area                       4317
# barrier                    4120
# building                   4322
# check_date                 4322
# contact:facebook           4322
# contact:instagram          4322
# description                4307
# ele                        4316
# email                      4322
# fee                        4283
# fence                      4322
# fixme                      4316
# flickr                     4322
# garden:type                4208
# gnis:feature_id            4311
# height                     4261
# last_checked               4321
# layer                      4286
# leisure                       0
# level                      4321
# lit                        4322
# loc_name                   4321
# location                   4316
# material                   4322
# name                       4171
# name:etymology             4319
# name:etymology:wikidata    4318
# name:hr                    4322
# natural                    4322
# note                       4320
# official_name              4322
# old_name                   4322
# opening_hours              4301
# opening_hours:signed       4322
# operator                   4305
# operator:type              4316
# phone                      4322
# recycling:compost          4308
# smoking                    4322
# source                     4252
# start_date                 4289
# surface                    4318
# type                       4305
# website                    4282
# wheelchair                 4322
# wikidata                   4303
# wikipedia                  4319
# geometry                      0
# dtype: int64

# %%
garden_details=garden_gdf[['id','geometry']]

# %%
garden_details.explore("id", legend=True)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d56c3a746fcfe0a5e64cc045de090350 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#
#     &lt;script src=&quot;https://code.jquery.com/ui/1.12.1/jquery-ui.js&quot;&gt;&lt;/script&gt;
#     &lt;script&gt;$( function() {
#         $( &quot;.maplegend&quot; ).draggable({
#             start: function (event, ui) {
#                 $(this).css({
#                     right: &quot;auto&quot;,
#                     top: &quot;auto&quot;,
#                     bottom: &quot;auto&quot;
#                 });
#             }
#         });
#     });
#     &lt;/script&gt;
#     &lt;style type=&#x27;text/css&#x27;&gt;
#       .maplegend {
#         position: absolute;
#         z-index:9999;
#         background-color: rgba(255, 255, 255, .8);
#         border-radius: 5px;
#         box-shadow: 0 0 15px rgba(0,0,0,0.2);
#         padding: 10px;
#         font: 12px/14px Arial, Helvetica, sans-serif;
#         right: 10px;
#         bottom: 20px;
#       }
#       .maplegend .legend-title {
#         text-align: left;
#         margin-bottom: 5px;
#         font-weight: bold;
#         }
#       .maplegend .legend-scale ul {
#         margin: 0;
#         margin-bottom: 0px;
#         padding: 0;
#         float: left;
#         list-style: none;
#         }
#       .maplegend .legend-scale ul li {
#         list-style: none;
#         margin-left: 0;
#         line-height: 16px;
#         margin-bottom: 2px;
#         }
#       .maplegend ul.legend-labels li span {
#         display: block;
#         float: left;
#         height: 14px;
#         width: 14px;
#         margin-right: 5px;
#         margin-left: 0;
#         border: 0px solid #ccc;
#         }
#       .maplegend .legend-source {
#         color: #777;
#         clear: both;
#         }
#       .maplegend a {
#         color: #777;
#         }
#     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#     &lt;div id=&#x27;maplegend id&#x27; class=&#x27;maplegend&#x27;&gt;
#         &lt;div class=&#x27;legend-title&#x27;&gt;id&lt;/div&gt;
#         &lt;div class=&#x27;legend-scale&#x27;&gt;
#             &lt;ul class=&#x27;legend-labels&#x27;&gt;
#                 &lt;li&gt;&lt;span style=&#x27;background:#1f77b4&#x27;&gt;&lt;/span&gt;node/10032566430&lt;/li&gt;
#                 &lt;li&gt;&lt;span style=&#x27;background:#1f77b4&#x27;&gt;&lt;/span&gt;node/11596393293&lt;/li&gt;
#                 &lt;li&gt;&lt;span style=&#x27;background:#1f77b4&#x27;&gt;&lt;/span&gt;node/11636206830&lt;/li&gt;
#                 &lt;li&gt;&lt;span style=&#x27;background:#1f77b4&#x27;&gt;&lt;/span&gt;node/11882458901&lt;/li&gt;
#                 &lt;li&gt;&lt;span style=&#x27;background:#1f77b4&#x27;&gt;&lt;/span&gt;node/11882671114&lt;/li&gt;
#                 &lt;li&gt;&lt;span style=&#x27;background:#1f77b4&#x27;&gt;&lt;/span&gt;node/11882671115&lt;/li&gt;
#                 &lt;li&gt;&lt;span style=&#x27;background:#1f77b4&#x27;&gt;&lt;/span&gt;node/11885218977&lt;/li&gt;
#                 &lt;li&gt;&lt;span style=&#x27;background:#1f77b4&#x27;&gt;&lt;/span&gt;node/11885218980&lt;/li&gt;
#                 &lt;li&gt;&lt;span style=&#x27;background:#1f77b4&#x27;&gt;&lt;/span&gt;node/11885218981&lt;/li&gt;
#                 &lt;li&gt;&lt;span style=&#x27;background:#1f77b4&#x27;&gt;&lt;/span&gt;node/11885218986&lt;/li&gt;
#                 &lt;li&gt;&lt;span style=&#x27;background:#1f77b4&#x27;&gt;&lt;/span&gt;node/11906951072&lt;/li&gt;
#                 &lt;li&gt;&lt;span style=&#x27;background:#1f77b4&#x27;&gt;&lt;/span&gt;node/11906951073&lt;/li&gt;
#                 &lt;li&gt;&lt;span style=&#x27;background:#1f77b4&#x27;&gt;&lt;/span&gt;node/1240900859&lt;/li&gt;
#                 &lt;li&gt;&lt;span style=&#x27;background:#1f77b4&#x27;&gt;&lt;/span&gt;node/1240900865&lt;/li&gt;
#                 &lt;li&gt;&lt;span style=&#x27;background:#1f77b4&#x27;&gt;&lt;/span&gt;node/1240901075&lt;/li&gt;
#                 &lt;li&gt;&lt;span style=&#x27;background:#1f77b4&#x27;&gt;&lt;/span&gt;node/2259027958&lt;/li&gt;
#                 &lt;li&gt;&lt;span style=&#x27;background:#1f77b4&#x27;&gt;&lt;/span&gt;node/3582082294&lt;/li&gt;
#                 &lt;li&gt;&lt;span style=&#x27;background:#1f77b4&#x27;&gt;&lt;/span&gt;node/4113336291&lt;/li&gt;
#                 &lt;li&gt;&lt;span style=&#x27;background:#1f77b4&#x27;&gt;&lt;/span&gt;node/4324586590&lt;/li&gt;
#                 &lt;li&gt;&lt;span style=&#x27;background:#1f77b4&#x27;&gt;&lt;/span&gt;node/4786386651&lt;/li&gt;
#                 &lt;li&gt;&lt;span style=&#x27;background:#1f77b4&#x27;&gt;&lt;/span&gt;node/6418623093&lt;/li&gt;
#                 &lt;li&gt;&lt;span style=&#x27;background:#1f77b4&#x27;&gt;&lt;/span&gt;node/748726582&lt;/li&gt;
#                 &lt;li&gt;&lt;span style=&#x27;background:#1f77b4&#x27;&gt;&lt;/span&gt;node/9109738749&lt;/li&gt;
#                 &lt;li&gt;&lt;span style=&#x27;background:#1f77b4&#x27;&gt;&lt;/span&gt;node/9934776538&lt;/li&gt;
#                 &lt;li&gt;&lt;span style=&#x27;background:#1f77b4&#x27;&gt;&lt;/span&gt;relation/10925250&lt;/li&gt;
#                 &lt;li&gt;&lt;span style=&#x27;background:#1f77b4&#x27;&gt;&lt;/span&gt;relation/12714129&

# %%
garden_gdf.shape
# Out:
# (4323, 58)
