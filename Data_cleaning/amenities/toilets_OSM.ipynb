# %%
import pandas as pd
import geopandas as gpd
import matplotlib.pyplot as plt
from shapely.geometry import Point

# %%
toiletsOSM_gdf = gpd.read_file("toilet_OSM.geojson")

# %%
pd.set_option('display.max_columns', None)
#display all columns not truncated

# %%
toiletsOSM_gdf
# Out:
#                    id               @id      access addr:city  \
# 0       way/160062003     way/160062003         yes      None
# 1       way/238356504     way/238356504        None      None
# 2       way/248166302     way/248166302         yes      None
# 3       way/248266458     way/248266458        None      None
# 4       way/248773597     way/248773597         yes      None
# ..                ...               ...         ...       ...
# 179  node/11870739703  node/11870739703  permissive      None
# 180  node/11870739704  node/11870739704  permissive      None
# 181  node/11955796822  node/11955796822         yes      None
# 182  node/11955796823  node/11955796823         yes      None
# 183  node/11971148597  node/11971148597         yes      None
#
#     addr:housenumber              addr:place addr:postcode addr:state  \
# 0               None                    None          None       None
# 1               None                    None          None       None
# ...

# %%
toiletsOSM_gdf.columns
# Out:
# Index(['id', '@id', 'access', 'addr:city', 'addr:housenumber', 'addr:place',
#        'addr:postcode', 'addr:state', 'addr:street', 'amenity', 'architect',
#        'building', 'building:colour', 'building:levels', 'building:material',
#        'changing_table', 'changing_table:location', 'charge', 'check_date',
#        'check_date:opening_hours', 'created_by', 'description',
#        'drinking_water', 'ele', 'fee', 'female', 'female:signed', 'fixme',
#        'gender_segregated', 'height', 'image', 'image:0', 'image:1', 'image:2',
#        'image:3', 'image:4', 'image:5', 'indoor', 'layer', 'level', 'male',
#        'male:signed', 'mapillary', 'name', 'note', 'nycdoitt:bin',
#        'opening_hours', 'opening_hours:signed', 'operator', 'portable',
#        'seasonal', 'source', 'source_ref', 'toilets:disposal',
#        'toilets:handwashing', 'toilets:paper_supplied', 'toilets:position',
#        'toilets:unisex', 'toilets:wheelchair', 'unisex', 'website',
# ...

# %%
toiletsOSM_gdf.head()
# Out:
#               id            @id access addr:city addr:housenumber  \
# 0  way/160062003  way/160062003    yes      None             None
# 1  way/238356504  way/238356504   None      None             None
# 2  way/248166302  way/248166302    yes      None              200
# 3  way/248266458  way/248266458   None      None             None
# 4  way/248773597  way/248773597    yes      None             None
#
#                addr:place addr:postcode addr:state addr:street  amenity  \
# 0                    None          None       None        None  toilets
# 1                    None          None       None        None  toilets
# 2  Washington Square Park          None       None        None  toilets
# 3                    None          None       None        None  toilets
# 4                    None          None       None        None  toilets
#
#   architect building building:colour building:levels building:material  \
# ...

# %%
toiletsOSM_gdf['name'].value_counts()
# Out:
# name
# Washington Square Park House            1
# Pier 45 Comfort Station                 1
# Payson Nature Center                    1
# Octagon Comfort Station                 1
# High Bridge Recreation Center           1
# Famous Famiglia                         1
# Tavern on the Green public restrooms    1
# Bryant Park public toilets              1
# Chelsea Park Toilets                    1
# Name: count, dtype: int64

# %%
toiletsOSM_gdf.shape
# Out:
# (184, 64)

# %%
toiletsOSM_gdf['access'].value_counts()
# Out:
# access
# yes           68
# permissive     5
# customers      3
# no             1
# Name: count, dtype: int64

# %%
toiletsOSM_gdf.isnull().sum()
# Out:
# id                     0
# @id                    0
# access               107
# addr:city            183
# addr:housenumber     175
#                     ...
# unisex               170
# website              181
# wheelchair           121
# wikimedia_commons    181
# geometry               0
# Length: 64, dtype: int64

# %%
toiletsOSM_gdf['addr:place'].isnull().sum()
# Out:
# 183

# %%
toiletsOSM_gdf=toiletsOSM_gdf[['id','name', 'geometry']]

# %%
toiletsOSM_gdf
# Out:
#                    id                          name  \
# 0       way/160062003                          None
# 1       way/238356504                          None
# 2       way/248166302  Washington Square Park House
# 3       way/248266458                          None
# 4       way/248773597                          None
# ..                ...                           ...
# 179  node/11870739703                          None
# 180  node/11870739704                          None
# 181  node/11955796822                          None
# 182  node/11955796823                          None
# 183  node/11971148597                          None
#
#                                               geometry
# 0    POLYGON ((-73.94618 40.84715, -73.94617 40.847...
# 1    POLYGON ((-73.95904 40.75327, -73.95908 40.753...
# 2    POLYGON ((-73.99834 40.73073, -73.99829 40.730...
# 3    POLYGON ((-73.98561 40.72422, -73.98557 40.724...
# 4    POLYGON ((-73.98951 40.73632, -73.98959 40.736...
# ...

# %%
toiletsOSM_gdf
# Out:
#                              name  \
# 0                            None
# 1                            None
# 2    Washington Square Park House
# 3                            None
# 4                            None
# ..                            ...
# 179                          None
# 180                          None
# 181                          None
# 182                          None
# 183                          None
#
#                                               geometry
# 0    POLYGON ((-73.94618 40.84715, -73.94617 40.847...
# 1    POLYGON ((-73.95904 40.75327, -73.95908 40.753...
# 2    POLYGON ((-73.99834 40.73073, -73.99829 40.730...
# 3    POLYGON ((-73.98561 40.72422, -73.98557 40.724...
# 4    POLYGON ((-73.98951 40.73632, -73.98959 40.736...
# ..                                                 ...
# 179                         POINT (-74.00524 40.72683)
# 180                         POINT (-74.00524 40.72687)
# ...

# %%
toiletsOSM_gdf
# Out:
#                              name  \
# 0                            None
# 1                            None
# 2    Washington Square Park House
# 3                            None
# 4                            None
# ..                            ...
# 179                          None
# 180                          None
# 181                          None
# 182                          None
# 183                          None
#
#                                               geometry
# 0    POLYGON ((-73.94618 40.84715, -73.94617 40.847...
# 1    POLYGON ((-73.95904 40.75327, -73.95908 40.753...
# 2    POLYGON ((-73.99834 40.73073, -73.99829 40.730...
# 3    POLYGON ((-73.98561 40.72422, -73.98557 40.724...
# 4    POLYGON ((-73.98951 40.73632, -73.98959 40.736...
# ..                                                 ...
# 179                         POINT (-74.00524 40.72683)
# 180                         POINT (-74.00524 40.72687)
# ...

# %%
#toiletsOSM_gdf.to_file('toiletsOSM_cleaned.geojson',driver='GeoJSON')

# %%
toiletsOSM_gdf.crs
# Out:
# <Geographic 2D CRS: EPSG:4326>
# Name: WGS 84
# Axis Info [ellipsoidal]:
# - Lat[north]: Geodetic latitude (degree)
# - Lon[east]: Geodetic longitude (degree)
# Area of Use:
# - undefined
# Datum: World Geodetic System 1984
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich
