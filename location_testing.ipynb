# %%
import pandas as pd
import geopandas as gpd
import numpy as np
from shapely.geometry import Point, shape, MultiPolygon
import geojson
from scipy.spatial import KDTree
from geopy.distance import geodesic
import matplotlib.pyplot as plt

# %%
"""
# Load the datasets
parks = gpd.read_file('park_zones_dpr.geojson')
taxi_zones = gpd.read_file('nyc_taxi_zones_tlc.geojson')
green_taxi_csv = pd.read_csv('2022_green_taxi.csv', nrows=100000)

"""
# Out:
# "\n# Load the datasets\nparks = gpd.read_file('park_zones_dpr.geojson')\ntaxi_zones = gpd.read_file('nyc_taxi_zones_tlc.geojson')\ngreen_taxi_csv = pd.read_csv('2022_green_taxi.csv', nrows=100000)\n\n"

# %%
green_taxi = pd.read_csv('2022_green_taxi.csv',delimiter=';', nrows=10000)

# %%
green_taxi.head()
# Out:
#    VendorID    lpep_pickup_datetime   lpep_dropoff_datetime  \
# 0         2  01/01/2022 12:14:21 AM  01/01/2022 12:15:33 AM
# 1         1  01/01/2022 12:20:55 AM  01/01/2022 12:29:38 AM
# 2         1  01/01/2022 12:57:02 AM  01/01/2022 01:13:14 AM
# 3         2  01/01/2022 12:07:42 AM  01/01/2022 12:15:57 AM
# 4         2  01/01/2022 12:07:50 AM  01/01/2022 12:28:52 AM
#
#   store_and_fwd_flag  RatecodeID  PULocationID  DOLocationID  passenger_count  \
# 0                  N           1            42            42                1
# 1                  N           1           116            41                1
# 2                  N           1            41           140                1
# 3                  N           1           181           181                1
# 4                  N           1            33           170                1
#
#    trip_distance  fare_amount  extra  mta_tax  tip_amount  tolls_amount  \
# 0           0.44          3.5   0.50      0.5        0.00           0.0
# 1           2.10          9.5   0.50      0.5        0.00           0.0
# 2           3.70         14.5   3.25      0.5        4.60           0.0
# 3           1.69          8.0   0.50      0.5        0.00           0.0
# 4           6.26         22.0   0.50      0.5        5.21           0.0
#
#    ehail_fee  improvement_surcharge  total_amount  payment_type  trip_type  \
# 0        NaN                    0.3          4.80             2          1
# 1        NaN                    0.3         10.80             2          1
# 2        NaN                    0.3         23.15             1          1
# 3        NaN                    0.3          9.30             2          1
# 4        NaN                    0.3         31.26             1          1
#
#    congestion_surcharge
# 0                  0.00
# 1                  0.00
# 2                  2.75
# 3                  0.00
# 4                  2.75

# %%
# Load the GeoJSON files
with open('nyc_taxi_zones_tlc.geojson', 'r') as f:
    taxi_zones_geojson = geojson.load(f)

# %%
# Filter the features based on the 'borough' property
filtered_features_taxi = [feature for feature in taxi_zones_geojson['features'] if feature['properties']['borough'] == 'Manhattan']

# Optionally convert to a DataFrame
taxi_zones_df = pd.json_normalize(filtered_features_taxi)

# Display the first few rows of the filtered DataFrame
print(taxi_zones_df.head())
# Out:
#       type geometry.type                               geometry.coordinates  \
# 0  Feature  MultiPolygon  [[[[-73.971774, 40.725821], [-73.971791, 40.72...
# 1  Feature  MultiPolygon  [[[[-73.959537, 40.798719], [-73.960045, 40.79...
# 2  Feature  MultiPolygon  [[[[-74.015658, 40.704833], [-74.015398, 40.70...
# 3  Feature  MultiPolygon  [[[[-74.012441, 40.719058], [-74.012816, 40.71...
# 4  Feature  MultiPolygon  [[[[-73.94774, 40.8096], [-73.945061, 40.80847...
#
#   properties.shape_area properties.objectid properties.shape_leng  \
# 0     0.000111871946192                   4       0.0435665270921
# 1    0.0000607235737749                  24       0.0469999619287
# 2    0.0000415116236727                  12       0.0366613013579
# 3     0.000149358592917                  13       0.0502813228631
# 4     0.000143093037737                  41        0.052793109453
#
#   properties.location_id    properties.zone properties.borough
# 0                      4      Alphabet City          Manhattan
# 1                     24       Bloomingdale          Manhattan
# 2                     12       Battery Park          Manhattan
# 3                     13  Battery Park City          Manhattan
# 4                     41     Central Harlem          Manhattan

# %%
with open('park_zones_dpr.geojson', 'r') as f:
    park_zones_geojson = geojson.load(f)

# %%
filtered_features_park = [feature for feature in park_zones_geojson['features'] if feature['properties']['borough'] == 'M']

# Optionally convert to a DataFrame
park_zones_df = pd.json_normalize(filtered_features_park)

# Display the first few rows of the filtered DataFrame
print(park_zones_df.head())
# Out:
#       type geometry.type                               geometry.coordinates  \
# 0  Feature  MultiPolygon  [[[[-73.976235, 40.795484], [-73.976234, 40.79...
# 1  Feature  MultiPolygon  [[[[-73.970957, 40.782456], [-73.971002, 40.78...
# 2  Feature  MultiPolygon  [[[[-73.926807, 40.784524], [-73.926623, 40.78...
# 3  Feature  MultiPolygon  [[[[-73.969931, 40.774692], [-73.970169, 40.77...
# 4  Feature  MultiPolygon  [[[[-73.962353, 40.814828], [-73.962056, 40.81...
#
#   properties.propname properties.retireddate properties.zipcode  \
# 0      Riverside Park                   None              10024
# 1        Central Park                   None              10024
# 2   Wards Island Park                   None              10035
# 3        Central Park                   None         1002310024
# 4      Riverside Park                   None              10024
#
#   properties.acres                                properties.location  \
# 0         4.070674               84th To 95th Sts Along Riverside Dr.
# 1       0.37274754                            81 St & Central Pk West
# 2       16.3972486  S/o Hell Gate Queens Span, E/o Odyssey House C...
# 3      35.78090067  S + W Sides Of Lake, N/o 72 St Transverse, Cen...
# 4       0.33775968                            W 124 St & Riverside Dr
#
#   properties.nys_assembly properties.councildistrict  ...  \
# 0                  69, 67                          6  ...
# 1                      69                          6  ...
# 2                      68                          8  ...
# 3              69, 67, 75                          6  ...
# 4                      70                          7  ...
#
#   properties.gispropnum properties.retired properties.communityboard  \
# 0                  M071              false                       107
# 1                  M010              false                       164
# 2                  M107              false                       111
# 3                  M010              false                       164
# 4                  M071              false                       109
#
#   properties.department properties.subcategory properties.precinct  \
# 0                  M-14                   None                  20
# 1                  M-13                   None                  22
# 2                 M-11R                   None                  25
# 3                  M-13                   None                  22
# 4                  M-14                   None                  26
#
#   properties.omppropid properties.sitename properties.nys_senate  \
# 0            M071-ZN07                None                    31
# 1             M010-164                None                    29
# 2            M107-ZN08                None                    29
# 3            M010-ZN20                None                    29
# 4              M071-31                None                    31
#
#   properties.borough
# 0                  M
# 1                  M
# 2                  M
# 3                  M
# 4                  M
#
# [5 rows x 22 columns]

# %%
# Function to sample the DataFrame safely
def safe_sample(df, n, random_state=1):
    if len(df) < n:
        return df.sample(n=len(df), random_state=random_state)
    else:
        return df.sample(n=n, random_state=random_state)

# %%
# Sample 100 rows from each DataFrame (if they have at least 10,000 rows)
taxi_zones_sample = safe_sample(taxi_zones_df, 100)
park_zones_sample = safe_sample(park_zones_df, 100)

# Display the samples (or you can save them or process further)
print(taxi_zones_sample.head())
print(park_zones_sample.head())
# Out:
#        type geometry.type                               geometry.coordinates  \
# 63  Feature  MultiPolygon  [[[[-73.931565, 40.869582], [-73.931414, 40.86...
# 31  Feature  MultiPolygon  [[[[-73.972196, 40.740403], [-73.972217, 40.74...
# 26  Feature  MultiPolygon  [[[[-73.922954, 40.858851], [-73.922828, 40.85...
# 36  Feature  MultiPolygon  [[[[-73.995809, 40.716645], [-73.996059, 40.71...
# 65  Feature  MultiPolygon  [[[[-74.0044, 40.762671], [-74.002201, 40.7617...
#
#    properties.shape_area properties.objectid properties.shape_leng  \
# 63     0.000438377341503                 243       0.0943314999364
# 31     0.000116455098947                 137       0.0461076242707
# 26    0.0000931462821313                 120       0.0832612702158
# 36    0.0000474789670369                 144       0.0276201668505
# 65     0.000281298327076                 246       0.0694671937437
#
#    properties.location_id            properties.zone properties.borough
# 63                    243   Washington Heights North          Manhattan
# 31                    137                   Kips Bay          Manhattan
# 26                    120            Highbridge Park          Manhattan
# 36                    144        Little Italy/NoLiTa          Manhattan
# 65                    246  West Chelsea/Hudson Yards          Manhattan
#         type geometry.type                               geometry.coordinates  \
# 182  Feature  MultiPolygon  [[[[-73.959143, 40.796479], [-73.959177, 40.79...
# 34   Feature  MultiPolygon  [[[[-73.947762, 40.839637], [-73.947322, 40.84...
# 110  Feature  MultiPolygon  [[[[-73.961452, 40.780367], [-73.961439, 40.78...
# 112  Feature  MultiPolygon  [[[[-74.014174, 40.701467], [-74.014174, 40.70...
# 226  Feature  MultiPolygon  [[[[-73.973529, 40.763766], [-73.973527, 40.76...
#
#       properties.propname properties.retireddate properties.zipcode  \
# 182          Central Park                   None              10025
# 34   Fort Washington Park                   None              10032
# 110          Central Park                   None              10024
# 112           The Battery                   None              10004
# 226          Central Park                   None         1001910023
#
#     properties.acres                                properties.location  \
# 182      22.40035888       CPW, N Of 100 Str, W Of West Dr, S Of 105 St
# 34        0.56450012  Within Zone 1A, Along Hudson River At Approxim...
# 110       0.83668203                                    85 St & 5th Ave
# 112       0.74591713                                  State & South Sts
# 226       1.38483504                        5 Ave Btw W 58 and W 60 Sts
#
#     properties.nys_assembly properties.councildistrict  ...  \
# 182                      68                          6  ...
# 34                       71                          7  ...
# 110                      69                          6  ...
# 112                      65                          1  ...
# 226                      75                          6  ...
#
#     properties.gispropnum properties.retired properties.communityboard  \
# 182                  M010              false                       164
# 34                   M028              false                       112
# 110                  M010              false                       164
# 112                  M005              false                       101
# 226                  M010              false                       164
#
#     properties.department properties.subcategory properties.precinct  \
# 182                  M-13                   None                   2
# 34                   M-14                   None                  33
# 110                  M-13                   None                  22
# 112                  M-01                   None                   1
# 226                  M-13                   None                  22
#
#     properties.omppropid properties.sitename properties.nys_senate  \
# 182            M010-ZN48                None                    29
# 34               M028-03                None                    31
# 110             M010-145                None                    29
# 112              M005-02                None                    26
# 226              M010-02                None                28, 29
#
#     properties.borough
# 182                  M
# 34                   M
# 110                  M
# 112                  M
# 226                  M
#
# [5 rows x 22 columns]

# %%
# Function to extract coordinates from a multipolygon
def extract_coordinates(geojson_obj):
    coordinates = []
    for feature in geojson_obj['features']:
        geom = shape(feature['geometry'])
        if isinstance(geom, MultiPolygon):
            for polygon in geom.geoms:
                for ring in polygon.exterior.coords:
                    coordinates.append((ring[1], ring[0]))  # (latitude, longitude)
        else:
            for ring in geom.exterior.coords:
                coordinates.append((ring[1], ring[0]))  # (latitude, longitude)
    return coordinates

# %%
# Get the coordinates for both datasets
taxi_zones_coordinates = extract_coordinates(taxi_zones_geojson)
park_zones_coordinates = extract_coordinates(park_zones_geojson)

# Create DataFrames to display the coordinates
taxi_zones_df = pd.DataFrame(taxi_zones_coordinates, columns=['Latitude', 'Longitude'])
park_zones_df = pd.DataFrame(park_zones_coordinates, columns=['Latitude', 'Longitude'])

# %%
# Display DataFrames
print("Taxi Zones Coordinates:")
print(taxi_zones_df.head())
# Out:
# Taxi Zones Coordinates:
#     Latitude  Longitude
# 0  40.694996 -74.184453
# 1  40.695095 -74.184489
# 2  40.695185 -74.184498
# 3  40.695878 -74.184381
# 4  40.696211 -74.184282

# %%
print("\nPark Zones Coordinates:")
print(park_zones_df)
# Out:
# Park Zones Coordinates:
#          Latitude  Longitude
# 0       40.627353 -74.100495
# 1       40.627440 -74.099656
# 2       40.627649 -74.099707
# 3       40.627721 -74.099146
# 4       40.627750 -74.098925
# ...           ...        ...
# 309199  40.564012 -74.096805
# 309200  40.564026 -74.096833
# 309201  40.564084 -74.096952
# 309202  40.564090 -74.096964
# 309203  40.564116 -74.097017
#
# [309204 rows x 2 columns]

# %%
# Use KDTree for fast nearest-neighbor lookup
taxi_coords = taxi_zones_df[['Latitude', 'Longitude']].to_numpy()
park_coords = park_zones_df[['Latitude', 'Longitude']].to_numpy()

# %%
tree = KDTree(taxi_coords)

# Find all park coordinates within 600 meters of any taxi coordinate
results = tree.query_ball_point(park_coords, r=0.006)

# %%
"""#Distance geodesic 
def calculate_distance(lat1, lon1, lat2, lon2):
    return geodesic((lat1, lon1), (lat2, lon2))
    """
# Out:
# '#Distance geodesic \ndef calculate_distance(lat1, lon1, lat2, lon2):\n    return geodesic((lat1, lon1), (lat2, lon2))\n    '

# %%
# Function to calculate the Euclidean distance
def calculate_distance(lat1, lon1, lat2, lon2):
    return np.sqrt((lat2 - lat1) ** 2 + (lon2 - lon1) ** 2)

# %%
# Initialize an empty list to store distances and filtered pairs
filtered_pairs = []

# Iterate over the results and store the pairs
for park_index, taxi_indices in enumerate(results):
    park_lat, park_lon = park_coords[park_index]
    for taxi_index in taxi_indices:
        taxi_lat, taxi_lon = taxi_coords[taxi_index]
        dist = calculate_distance(park_lat, park_lon,taxi_lat, taxi_lon,)
        filtered_pairs.append({
            'Taxi_Latitude': taxi_lat,
            'Taxi_Longitude': taxi_lon,
            'Park_Latitude': park_lat,
            'Park_Longitude': park_lon,
            'Distance': dist
        })

# %%
"""for park_index, taxi_indices in enumerate(results):
    park_lat, park_lon = park_coords[park_index]
    for taxi_index in taxi_indices:
        taxi_lat, taxi_lon = taxi_coords[taxi_index]
        dist = geodesic((taxi_lat, taxi_lon), (park_lat, park_lon))
        if dist <= 600:  # 600 meters
            filtered_pairs.append({
                'Taxi_Latitude': taxi_lat,
                'Taxi_Longitude': taxi_lon,
                'Park_Latitude': park_lat,
                'Park_Longitude': park_lon,
                'Distance': dist
            })
        """
# Out:
# "for park_index, taxi_indices in enumerate(results):\n    park_lat, park_lon = park_coords[park_index]\n    for taxi_index in taxi_indices:\n        taxi_lat, taxi_lon = taxi_coords[taxi_index]\n        dist = geodesic((taxi_lat, taxi_lon), (park_lat, park_lon))\n        if dist <= 600:  # 600 meters\n            filtered_pairs.append({\n                'Taxi_Latitude': taxi_lat,\n                'Taxi_Longitude': taxi_lon,\n                'Park_Latitude': park_lat,\n                'Park_Longitude': park_lon,\n                'Distance': dist\n            })\n        "

# %% [markdown]
# FOR FUTURE

# %%
# Create a DataFrame for filtered pairs within 600 meters
filtered_df_600metres = pd.DataFrame(filtered_pairs)

# %%
# Save the filtered DataFrame to a CSV file
#filtered_df.to_csv('filtered_pairs_within_600_meters.csv', index=False)
#print("Filtered data saved to 'filtered_pairs_within_600_meters.csv'")

# %%
# Display the filtered DataFrame
print("Filtered Pairs within 600 meters:")
print(filtered_df_600metres)
# Out:
# Filtered Pairs within 600 meters:
#           Taxi_Latitude  Taxi_Longitude  Park_Latitude  Park_Longitude  \
# 0             40.623202      -74.095335      40.627721      -74.099146
# 1             40.623202      -74.095335      40.627721      -74.099146
# 2             40.622329      -74.096400      40.627750      -74.098925
# 3             40.623202      -74.095335      40.627750      -74.098925
# 4             40.623202      -74.095335      40.627750      -74.098925
# ...                 ...             ...            ...             ...
# 31919650      40.559005      -74.099296      40.564116      -74.097017
# 31919651      40.558964      -74.099380      40.564116      -74.097017
# 31919652      40.559141      -74.099718      40.564116      -74.097017
# 31919653      40.559071      -74.099929      40.564116      -74.097017
# 31919654      40.559071      -74.099929      40.564116      -74.097017
#
#           Distance
# 0         0.005911
# 1         0.005911
# 2         0.005980
# 3         0.005794
# 4         0.005794
# ...            ...
# 31919650  0.005596
# 31919651  0.005668
# 31919652  0.005661
# 31919653  0.005825
# 31919654  0.005825
#
# [31919655 rows x 5 columns]

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))
plt.hist(filtered_df_600metres['Distance'], bins=50, edgecolor='k', alpha=0.7)
plt.title('Histogram of Distances')
plt.xlabel('Distance')
plt.ylabel('Frequency')
plt.show()

# %%
# Merge the green taxi data with the location data using PULocationID and DOLocationID
taxi_zones_df['location_id'] = taxi_zones_df.index + 1  #create a unique identifier for each row.
green_taxi = green_taxi.rename(columns={'PULocationID': 'PUlocationID', 'DOLocationID': 'DOlocationID'})

# Merge with pickup locations
pickup_locations = green_taxi.merge(taxi_zones_df, left_on='PUlocationID', right_on='location_id')

# Merge with dropoff locations
dropoff_locations = green_taxi.merge(taxi_zones_df, left_on='DOlocationID', right_on='location_id')

# %%
#Create GeoDataFrames for pickup and dropoff locations
pickup_gdf = gpd.GeoDataFrame(pickup_locations, geometry=gpd.points_from_xy(pickup_locations.Longitude, pickup_locations.Latitude))
dropoff_gdf = gpd.GeoDataFrame(dropoff_locations, geometry=gpd.points_from_xy(dropoff_locations.Longitude, dropoff_locations.Latitude))

# %%
print(pickup_gdf.head())
# Out:
#    VendorID    lpep_pickup_datetime   lpep_dropoff_datetime  \
# 0         2  01/01/2022 12:14:21 AM  01/01/2022 12:15:33 AM
# 1         1  01/01/2022 12:20:55 AM  01/01/2022 12:29:38 AM
# 2         1  01/01/2022 12:57:02 AM  01/01/2022 01:13:14 AM
# 3         2  01/01/2022 12:07:42 AM  01/01/2022 12:15:57 AM
# 4         2  01/01/2022 12:07:50 AM  01/01/2022 12:28:52 AM
#
#   store_and_fwd_flag  RatecodeID  PUlocationID  DOlocationID  passenger_count  \
# 0                  N           1            42            42                1
# 1                  N           1           116            41                1
# 2                  N           1            41           140                1
# 3                  N           1           181           181                1
# 4                  N           1            33           170                1
#
#    trip_distance  fare_amount  ...  ehail_fee  improvement_surcharge  \
# 0           0.44          3.5  ...        NaN                    0.3
# 1           2.10          9.5  ...        NaN                    0.3
# 2           3.70         14.5  ...        NaN                    0.3
# 3           1.69          8.0  ...        NaN                    0.3
# 4           6.26         22.0  ...        NaN                    0.3
#
#    total_amount  payment_type  trip_type  congestion_surcharge   Latitude  \
# 0          4.80             2          1                  0.00  40.707470
# 1         10.80             2          1                  0.00  40.688030
# 2         23.15             1          1                  2.75  40.707380
# 3          9.30             2          1                  0.00  40.672028
# 4         31.26             1          1                  2.75  40.706138
#
#    Longitude  location_id                    geometry
# 0 -74.175381           42  POINT (-74.17538 40.70747)
# 1 -74.165769          116  POINT (-74.16577 40.68803)
# 2 -74.175660           41  POINT (-74.17566 40.70738)
# 3 -74.182140          181  POINT (-74.18214 40.67203)
# 4 -74.176992           33  POINT (-74.17699 40.70614)
#
# [5 rows x 24 columns]

# %%
print(dropoff_gdf.head())
# Out:
#    VendorID    lpep_pickup_datetime   lpep_dropoff_datetime  \
# 0         2  01/01/2022 12:14:21 AM  01/01/2022 12:15:33 AM
# 1         1  01/01/2022 12:20:55 AM  01/01/2022 12:29:38 AM
# 2         1  01/01/2022 12:57:02 AM  01/01/2022 01:13:14 AM
# 3         2  01/01/2022 12:07:42 AM  01/01/2022 12:15:57 AM
# 4         2  01/01/2022 12:07:50 AM  01/01/2022 12:28:52 AM
#
#   store_and_fwd_flag  RatecodeID  PUlocationID  DOlocationID  passenger_count  \
# 0                  N           1            42            42                1
# 1                  N           1           116            41                1
# 2                  N           1            41           140                1
# 3                  N           1           181           181                1
# 4                  N           1            33           170                1
#
#    trip_distance  fare_amount  ...  ehail_fee  improvement_surcharge  \
# 0           0.44          3.5  ...        NaN                    0.3
# 1           2.10          9.5  ...        NaN                    0.3
# 2           3.70         14.5  ...        NaN                    0.3
# 3           1.69          8.0  ...        NaN                    0.3
# 4           6.26         22.0  ...        NaN                    0.3
#
#    total_amount  payment_type  trip_type  congestion_surcharge   Latitude  \
# 0          4.80             2          1                  0.00  40.707470
# 1         10.80             2          1                  0.00  40.707380
# 2         23.15             1          1                  2.75  40.680875
# 3          9.30             2          1                  0.00  40.672028
# 4         31.26             1          1                  2.75  40.671317
#
#    Longitude  location_id                    geometry
# 0 -74.175381           42  POINT (-74.17538 40.70747)
# 1 -74.175660           41  POINT (-74.17566 40.70738)
# 2 -74.169954          140  POINT (-74.16995 40.68088)
# 3 -74.182140          181  POINT (-74.18214 40.67203)
# 4 -74.177784          170  POINT (-74.17778 40.67132)
#
# [5 rows x 24 columns]

# %%
# Set the coordinate reference system (CRS) to WGS84
pickup_gdf.set_crs(epsg=4326, inplace=True)
dropoff_gdf.set_crs(epsg=4326, inplace=True)
# Out:
#       VendorID    lpep_pickup_datetime   lpep_dropoff_datetime  \
# 0            2  01/01/2022 12:14:21 AM  01/01/2022 12:15:33 AM
# 1            1  01/01/2022 12:20:55 AM  01/01/2022 12:29:38 AM
# 2            1  01/01/2022 12:57:02 AM  01/01/2022 01:13:14 AM
# 3            2  01/01/2022 12:07:42 AM  01/01/2022 12:15:57 AM
# 4            2  01/01/2022 12:07:50 AM  01/01/2022 12:28:52 AM
# ...        ...                     ...                     ...
# 9995         2  01/06/2022 03:36:42 PM  01/06/2022 03:50:38 PM
# 9996         2  01/06/2022 03:07:59 PM  01/06/2022 03:20:25 PM
# 9997         2  01/06/2022 03:47:05 PM  01/06/2022 04:07:13 PM
# 9998         2  01/06/2022 03:44:23 PM  01/06/2022 03:54:36 PM
# 9999         2  01/06/2022 03:08:54 PM  01/06/2022 03:25:27 PM
#
#      store_and_fwd_flag  RatecodeID  PUlocationID  DOlocationID  \
# 0                     N           1            42            42
# 1                     N           1           116            41
# 2                     N           1            41           140
# 3                     N           1           181           181
# 4                     N           1            33           170
# ...                 ...         ...           ...           ...
# 9995                  N           1           181           188
# 9996                  N           1           116            24
# 9997                  N           1            41           200
# 9998                  N           1            42            41
# 9999                  N           1            52           256
#
#       passenger_count  trip_distance  fare_amount  ...  ehail_fee  \
# 0                   1           0.44          3.5  ...        NaN
# 1                   1           2.10          9.5  ...        NaN
# 2                   1           3.70         14.5  ...        NaN
# 3                   1           1.69          8.0  ...        NaN
# 4                   1           6.26         22.0  ...        NaN
# ...               ...            ...          ...  ...        ...
# 9995                1           2.07         11.0  ...        NaN
# 9996                1           1.87         10.5  ...        NaN
# 9997                1           8.54         25.5  ...        NaN
# 9998                1           1.23          8.0  ...        NaN
# 9999                1           4.63         16.5  ...        NaN
#
#       improvement_surcharge  total_amount  payment_type  trip_type  \
# 0                       0.3          4.80             2          1
# 1                       0.3         10.80             2          1
# 2                       0.3         23.15             1          1
# 3                       0.3          9.30             2          1
# 4                       0.3         31.26             1          1
# ...                     ...           ...           ...        ...
# 9995                    0.3         11.80             2          1
# 9996                    0.3         11.30             2          1
# 9997                    0.3         38.09             1          1
# 9998                    0.3         11.44             1          1
# 9999                    0.3         20.76             1          1
#
#       congestion_surcharge   Latitude  Longitude  location_id  \
# 0                     0.00  40.707470 -74.175381           42
# 1                     0.00  40.707380 -74.175660           41
# 2                     2.75  40.680875 -74.169954          140
# 3                     0.00  40.672028 -74.182140          181
# 4                     2.75  40.671317 -74.177784          170
# ...                    ...        ...        ...          ...
# 9995                  0.00  40.673909 -74.185479          188
# 9996                  0.00  40.704392 -74.181807           24
# 9997                  0.00  40.680794 -74.189700          200
# 9998                  0.00  40.707380 -74.175660           41
# 9999                  0.00  40.628051 -73.819997          256
#
#                         geometry
# 0     POINT (-74.17538 40.70747)
# 1     POINT (-74.17566 40.70738)
# 2     POINT (-74.16995 40.68088)
# 3     POINT (-74.18214 40.67203)
# 4     POINT (-74.17778 40.67132)
# ...                          ...
# 9995  POINT (-74.18548 40.67391)
# 9996  POINT (-74.18181 40.70439)
# 9997  POINT (-74.18970 40.68079)
# 9998  POINT (-74.17566 40.70738)
# 9999  POINT (-73.82000 40.62805)
#
# [10000 rows x 24 columns]

# %%
# %%
# Perform spatial joins to find nearby pickups and drop-offs
nearby_pickups = gpd.sjoin(pickup_gdf, park_gdf, how='inner', op='within')
nearby_dropoffs = gpd.sjoin(dropoff_gdf, park_gdf, how='inner', op='within')

# %%
# %%
# Calculate busyness by summing the passenger counts
busyness = nearby_pickups.groupby(['Latitude_right', 'Longitude_right'])['passenger_count'].sum().reset_index(name='Pickup_Passenger_Count')
dropoff_busyness = nearby_dropoffs.groupby(['Latitude_right', 'Longitude_right'])['passenger_count'].sum().reset_index(name='Dropoff_Passenger_Count')

# Merge the busyness data
busyness_df = pd.merge(busyness, dropoff_busyness, on=['Latitude_right', 'Longitude_right'], how='outer').fillna(0)
busyness_df['Total_Passenger_Count'] = busyness_df['Pickup_Passenger_Count'] + busyness_df['Dropoff_Passenger_Count']

# %%
"""# Assess busyness by calculating the sum of passenger counts within the 600-meter radius
busyness = []
for idx, row in filtered_df_600metres.iterrows():
    park_point = Point(row['Park_Longitude'], row['Park_Latitude'])
    buffer = park_point.buffer(0.006)
    nearby_pickups = pickup_gdf[pickup_gdf.geometry.within(buffer)]
    nearby_dropoffs = dropoff_gdf[dropoff_gdf.geometry.within(buffer)]
    total_passengers = nearby_pickups['passenger_count'].sum() + nearby_dropoffs['passenger_count'].sum()
    busyness.append({
        'Park_Latitude': row['Park_Latitude'],
        'Park_Longitude': row['Park_Longitude'],
        'Total_Passenger_Count': total_passengers,
        'Pickup_Count': len(nearby_pickups),
        'Dropoff_Count': len(nearby_dropoffs)
    })
"""
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[30], line 7
#       5 buffer = park_point.buffer(0.006)
#       6 nearby_pickups = pickup_gdf[pickup_gdf.geometry.within(buffer)]
# ----> 7 nearby_dropoffs = dropoff_gdf[dropoff_gdf.geometry.within(buffer)]
#       8 total_passengers = nearby_pickups['passenger_count'].sum() + nearby_dropoffs['passenger_count'].sum()
#       9 busyness.append({
#      10     'Park_Latitude': row['Park_Latitude'],
#      11     'Park_Longitude': row['Park_Longitude'],
#    (...)
#      14     'Dropoff_Count': len(nearby_dropoffs)
#      15 })
#
# File c:\Users\adi17\anaconda3\envs\comp47350py311\Lib\site-packages\geopandas\base.py:2254, in GeoPandasBase.within(self, other, align)
#    2142 def within(self, other, align=True):
#    2143     """Returns a ``Series`` of ``dtype('bool')`` with value ``True`` for
#    2144     each aligned geometry that is within `other`.
#    2145
#    (...)
#    2252     GeoSeries.contains
#    2253     """
# -> 2254     return _binary_op("within", self, other, align)
#
# File c:\Users\adi17\anaconda3\envs\comp47350py311\Lib\site-packages\geopandas\base.py:63, in _binary_op(op, this, other, align, *args, **kwargs)
#      60 def _binary_op(op, this, other, align, *args, **kwargs):
#      61     # type: (str, GeoSeries, GeoSeries, args/kwargs) -> Series[bool/float]
#      62     """Binary operation on GeoSeries objects that returns a Series"""
# ---> 63     data, index = _delegate_binary_method(op, this, other, align, *args, **kwargs)
#      64     return Series(data, index=index)
#
# File c:\Users\adi17\anaconda3\envs\comp47350py311\Lib\site-packages\geopandas\base.py:47, in _delegate_binary_method(op, this, other, align, *args, **kwargs)
#      44 else:
#      45     raise TypeError(type(this), type(other))
# ---> 47 data = getattr(a_this, op)(other, *args, **kwargs)
#      48 return data, this.index
#
# File c:\Users\adi17\anaconda3\envs\comp47350py311\Lib\site-packages\geopandas\array.py:641, in GeometryArray.within(self, other)
#     640 def within(self, other):
# --> 641     return self._binary_method("within", self, other)
#
# File c:\Users\adi17\anaconda3\envs\comp47350py311\Lib\site-packages\geopandas\array.py:611, in GeometryArray._binary_method(op, left, right, **kwargs)
#     608         _crs_mismatch_warn(left, right, stacklevel=7)
#     609     right = right._data
# --> 611 return getattr(vectorized, op)(left._data, right, **kwargs)
#
# File c:\Users\adi17\anaconda3\envs\comp47350py311\Lib\site-packages\geopandas\_vectorized.py:891, in within(data, other)
#     889 def within(data, other):
#     890     if compat.USE_SHAPELY_20:
# --> 891         return shapely.within(data, other)
#     892     elif compat.USE_PYGEOS:
#     893         return _binary_method("within", data, other)
#
# File c:\Users\adi17\anaconda3\envs\comp47350py311\Lib\site-packages\shapely\decorators.py:77, in multithreading_enabled.<locals>.wrapped(*args, **kwargs)
#      75     for arr in array_args:
#      76         arr.flags.writeable = False
# ---> 77     return func(*args, **kwargs)
#      78 finally:
#      79     for arr, old_flag in zip(array_args, old_flags):
#
# File c:\Users\adi17\anaconda3\envs\comp47350py311\Lib\site-packages\shapely\predicates.py:923, in within(a, b, **kwargs)
#     875 @multithreading_enabled
#     876 def within(a, b, **kwargs):
#     877     """Returns True if geometry A is completely inside geometry B.
#     878
#     879     A is within B if no points of A lie in the exterior of B and at least one
#    (...)
#     921     False
#     922     """
# --> 923     return lib.within(a, b, **kwargs)
#
# KeyboardInterrupt:

# %%
# Create a DataFrame to display the busyness around parks
busyness_df = pd.DataFrame(busyness)

# Display the busyness DataFrame
print("Busyness around parks within 600 meters:")
print(busyness_df.head())

# %%
# %%
# Plot using matplotlib
fig, ax = plt.subplots(figsize=(15, 15))
base = park_zones_df.plot(ax=ax, color='green', alpha=0.5)
pickup_gdf.plot(ax=base, marker='o', color='red', markersize=1, alpha=0.3, label='Pickups')
dropoff_gdf.plot(ax=base, marker='x', color='blue', markersize=1, alpha=0.3, label='Drop-offs')
plt.legend()
plt.show()

# %%
import folium

m = folium.Map(location=[40.7831, -73.9712], zoom_start=12)

# %%
# Add park zones to the map
for _, park in park_zones_df.iterrows():
    folium.GeoJson(park['geometry'], style_function=lambda x: {'color': 'green', 'weight': 2, 'fillOpacity': 0.5}).add_to(m)

# Add pickup and dropoff points
for _, row in pickup_gdf.iterrows():
    folium.CircleMarker(location=[row.geometry.y, row.geometry.x], radius=1, color='red', fill=True).add_to(m)

for _, row in dropoff_gdf.iterrows():
    folium.CircleMarker(location=[row.geometry.y, row.geometry.x], radius=1, color='blue', fill=True).add_to(m)

# %%
# Save or display the map
m.save('manhattan_taxi_parks.html')
